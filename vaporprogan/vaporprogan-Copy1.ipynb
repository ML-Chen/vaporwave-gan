# %% [markdown]
# # VaporProGAN
#
# Modified from Fabian Nguyen's code at https://www.kaggle.com/fnguyen/vaporprogan

# %% [markdown]
# # Training

# %%
import math

res = 256  # resolution of the images, e.g., 256x256
# number of growth phase, e.g. 3 = 16x16 images, 6 = 128x128 images
n_blocks = int(math.log(res, 2) - 1)
# size of the latent space
latent_dim = 100

# %% [markdown]
# ## Image data (one-time)
#
# Originally, the training data was sourced from r/VaporwaveArt subreddit and provides us with 909 images that have been resized to 128x128 pixel images and converted to arrays using PIL. All 909 images were converted into one 909x128x128x3 Numpy array.
#
# Our newly scraped set of ~15,000 images is 256x256, so we will process those into a Numpy array.
#
# We will have to modify the code to work with 256x256 images.

# %%
# Modified from DomTomCat's answer at https://stackoverflow.com/a/37747559, CC-BY-SA 4.0

import cv2
import glob
import numpy as np
from PIL import Image

X_data = []
files = glob.glob(r"D:\Dropbox (GaTech)\vaporwave\256x256png\*.png")
for myFile in files:
    print(myFile)
    
    image = Image.open(myFile).convert('RGB')
    image.load() # required for png.split()
    image = np.array(image)
 
    if image is None or image.shape != (resolution, resolution, 3):
        print(f'This image is bad: {myFile} {image.shape if image is not None else "None"}')
    else:
        X_data.append(image)

print('X_data shape:', np.array(X_data).shape)
# Out:
# D:\Dropbox (GaTech)\vaporwave\256x256png\! ! ! ! ! - (millennium-toothpick).png
# D:\Dropbox (GaTech)\vaporwave\256x256png\! - (CodaShark).png
# D:\Dropbox (GaTech)\vaporwave\256x256png\! 9 . 9 9 - (tymcgo).png
# D:\Dropbox (GaTech)\vaporwave\256x256png\# B L E S S E D - (derpfaced).png
# D:\Dropbox (GaTech)\vaporwave\256x256png\# n o f i l t e r - (DonJonesUK).png
# D:\Dropbox (GaTech)\vaporwave\256x256png\# S T A R T - (SlickThiccRick).png
# D:\Dropbox (GaTech)\vaporwave\256x256png\#cover - (Deleted).png
# D:\Dropbox (GaTech)\vaporwave\256x256png\#DeadMeta. #Serena - (METAPRISE_APPS).png
# D:\Dropbox (GaTech)\vaporwave\256x256png\#free #vape imgur.com_a_4UCRK - (Keybraker).png
# D:\Dropbox (GaTech)\vaporwave\256x256png\#free - (Deleted).png
# D:\Dropbox (GaTech)\vaporwave\256x256png\#RIP2017 - A bit post-vaporwave - (rpeg).png
# D:\Dropbox (GaTech)\vaporwave\256x256png\#Ryoko - (kthuluu66).png
# D:\Dropbox (GaTech)\vaporwave\256x256png\#sadboysunset - (heyitschet).png
# D:\Dropbox (GaTech)\vaporwave\256x256png\#sadboysunset MK2 - (heyitschet).png
# D:\Dropbox (GaTech)\vaporwave\256x256png\#Seinfeld - (kthuluu66).png
# D:\Dropbox (GaTech)\vaporwave\256x256png\#ShadeprintHomeEntertainment (2015) _ [Shadeprint] - (Shadeprint).png
# D:\Dropbox (GaTech)\vaporwave\256x256png\#synthhop ⓐⓔⓢⓣⓗⓔⓣⓘⓒ - (theTyreeD).png
# D:\Dropbox (GaTech)\vaporwave\256x256png\#thaiwave - (theTyreeD).png
# D:\Dropbox (GaTech)\vaporwave\256x256png\#truestory - (Dankylynn).png
# D:\Dropbox (GaTech)\vaporwave\256x256png\#WHY!_ _ #なぜ！？ - (DanceChacDance).png
# D:\Dropbox (GaTech)\vaporwave\256x256png\#Δ''super s a d ㊚new +={ │ ∇ ∀ p o r w ∆ v ∈ 2016 │ }-=+㊛ video-m i x-o-rama''Δ# - (marcrivas).png
# D:\Dropbox (GaTech)\vaporwave\256x256png\$ View - (Gluet_Max).png
# D:\Dropbox (GaTech)\vaporwave\256x256png\$$$ @NEO-T0KY0RL3ANS $$$ - (KreweofVaporwave).png
# D:\Dropbox (GaTech)\vaporwave\256x256png\$1,000,000 - (throwaway420blazeitm).png
# D:\Dropbox (GaTech)\vaporwave\256x256png\$hills - (drop_trout).png
# D:\Dropbox (GaTech)\vaporwave\256x256png\$hr00_____05 - (jrdsctt).png
# D:\Dropbox (GaTech)\vaporwave\256x256png\$k1n2_01 - (jrdsctt).png
# D:\Dropbox (GaTech)\vaporwave\256x256png\$k1n2_02 - (jrdsctt).png
# D:\Dropbox (GaTech)\vaporwave\256x256png\$k1n2_09 - (jrdsctt).png
# D:\Dropbox (GaTech)\vaporwave\256x256png\$k1n2_10 - (jrdsctt).png
# D:\Dropbox (GaTech)\vaporwave\256x256png\$k1n2_14 (MakersPlace Exclusive Color Variant) - (jrdsctt).png
# D:\Dropbox (GaTech)\vaporwave\256x256png\$k1n2_14 - (jrdsctt).png
# D:\Dropbox (GaTech)\vaporwave\256x256png\$k1n_02 - (jrdsctt).png
# D:\Dropbox (GaTech)\vaporwave\256x256png\$k1n_03 - (jrdsctt).png
# D:\Dropbox (GaTech)\vaporwave\256x256png\$k1n_04 - (jrdsctt).png
# D:\Dropbox (GaTech)\vaporwave\256x256png\$k1n_05 - (jrdsctt).png
# D:\Dropbox (GaTech)\vaporwave\256x256png\$k1n_06 - (jrdsctt).png
# D:\Dropbox (GaTech)\vaporwave\256x256png\$k1n_07 - (jrdsctt).png
# D:\Dropbox (GaTech)\vaporwave\256x256png\$k1n_08 - (jrdsctt).png
# D:\Dropbox (GaTech)\vaporwave\256x256png\$k1n_09_v2 - (jrdsctt).png
# D:\Dropbox (GaTech)\vaporwave\256x256png\$k1n_10 - (jrdsctt).png
# D:\Dropbox (GaTech)\vaporwave\256x256png\$k1n_13_v2 - (jrdsctt).png
# D:\Dropbox (GaTech)\vaporwave\256x256png\$k1n_15 - (jrdsctt).png
# D:\Dropbox (GaTech)\vaporwave\256x256png\$k1n_16_v2 - (jrdsctt).png
# D:\Dropbox (GaTech)\vaporwave\256x256png\$k1n_17 - (jrdsctt).png
# D:\Dropbox (GaTech)\vaporwave\256x256png\$k1n_17_v2 - (jrdsctt).png
# D:\Dropbox (GaTech)\vaporwave\256x256png\$k1n_19 - (jrdsctt).png
# D:\Dropbox (GaTech)\vaporwave\256x256png\$k1n_20 - (jrdsctt).png
# D:\Dropbox (GaTech)\vaporwave\256x256png\$k1n_23 - (jrdsctt).png
# D:\Dropbox (GaTech)\vaporwave\256x256png\$k1n_25 - (jrdsctt).png
# D:\Dropbox (GaTech)\vaporwave\256x256png\$k1n_26 - (jrdsctt).png
# D:\Dropbox (GaTech)\vaporwave\256x256png\$k1n_27 - (jrdsctt).png
# D:\Dropbox (GaTech)\vaporwave\256x256png\$k1n_31 - (jrdsctt).png
# D:\Dropbox (GaTech)\vaporwave\256x256png\$k1n_32 - (jrdsctt).png
# D:\Dropbox (GaTech)\vaporwave\256x256png\$uicideboy$ - (ChamanOfTheIsla).png
# D:\Dropbox (GaTech)\vaporwave\256x256png\&gt; &gt; &gt; Go Back_ [yes] [no] - (SheepyTurtle).png
# D:\Dropbox (GaTech)\vaporwave\256x256png\&gt; U N L O C K _ - (diy4lyfe).png
# D:\Dropbox (GaTech)\vaporwave\256x256png\&gt;&gt;lonely &gt;&gt;road - (chinese_charmander).png
# D:\Dropbox (GaTech)\vaporwave\256x256png\&gt;. B E R M U D A - (littleshiba).png
# D:\Dropbox (GaTech)\vaporwave\256x256png\&gt;Aesthetic - (SSGerman).png
# D:\Dropbox (GaTech)\vaporwave\256x256png\&gt;forget_ m e __ - (tymcgo).png
# D:\Dropbox (GaTech)\vaporwave\256x256png\&gt;_&lt; - (0Bluefox0).png
# D:\Dropbox (GaTech)\vaporwave\256x256png\&gt;_ＡＬＬ ＴＨＡＴ ＧＬＩＴＴＥＲＳ - (littleshiba).png
# D:\Dropbox (GaTech)\vaporwave\256x256png\&lt; s a d b e e p i n g n o i s e s &gt; - (mrnovember5).png
# D:\Dropbox (GaTech)\vaporwave\256x256png\&lt;&lt; my mind &gt;&gt; - (LDKRP).png
# D:\Dropbox (GaTech)\vaporwave\256x256png\&lt;3 - (jakeyboii217).png
# D:\Dropbox (GaTech)\vaporwave\256x256png\&lt;3 - (Mnjaaaau).png
# D:\Dropbox (GaTech)\vaporwave\256x256png\&lt;m i s s i n g&gt; _ &lt;y o u&gt; - (seth_startix).png
# D:\Dropbox (GaTech)\vaporwave\256x256png\&lt;Summer Rental&gt; - (seth_startix).png
# D:\Dropbox (GaTech)\vaporwave\256x256png\&lt;y83rpx2_04 - (jrdsctt).png
# D:\Dropbox (GaTech)\vaporwave\256x256png\&lt;y83rpx2_06 - (jrdsctt).png
# D:\Dropbox (GaTech)\vaporwave\256x256png\&lt;y83rpx2_08 - (jrdsctt).png
# D:\Dropbox (GaTech)\vaporwave\256x256png\&lt;y83rpx2_09 - (jrdsctt) - 2.png
# D:\Dropbox (GaTech)\vaporwave\256x256png\&lt;y83rpx2_09 - (jrdsctt).png
# D:\Dropbox (GaTech)\vaporwave\256x256png\&lt;y83rpx2_11 - (jrdsctt).png
# D:\Dropbox (GaTech)\vaporwave\256x256png\&lt;y83rpx2_14 - (jrdsctt).png
# D:\Dropbox (GaTech)\vaporwave\256x256png\&lt;y83rpx2_16 - (jrdsctt).png
# D:\Dropbox (GaTech)\vaporwave\256x256png\&lt;y83rpx2_18 - (jrdsctt).png
# D:\Dropbox (GaTech)\vaporwave\256x256png\&lt;y83rpx2_19 - (jrdsctt).png
# D:\Dropbox (GaTech)\vaporwave\256x256png\&lt;y83rpx2_20 - (jrdsctt).png
# D:\Dropbox (GaTech)\vaporwave\256x256png\&lt;y83rpx2_21 - (jrdsctt).png
# D:\Dropbox (GaTech)\vaporwave\256x256png\&lt;y83rpx2_22 - (jrdsctt).png
# D:\Dropbox (GaTech)\vaporwave\256x256png\&lt;y83rpx2_24 - (jrdsctt).png
# D:\Dropbox (GaTech)\vaporwave\256x256png\&lt;y83rpx2_27 - (jrdsctt).png
# D:\Dropbox (GaTech)\vaporwave\256x256png\&lt;y83rpx2_30 - (jrdsctt).png
# D:\Dropbox (GaTech)\vaporwave\256x256png\&lt;y83rpx2_32 - (jrdsctt).png
# D:\Dropbox (GaTech)\vaporwave\256x256png\&lt;y83rpx_11 - (Deleted).png
# D:\Dropbox (GaTech)\vaporwave\256x256png\&lt;y83rpx_12 - (jrdsctt).png
# D:\Dropbox (GaTech)\vaporwave\256x256png\&lt;y83rpx_13 - (jrdsctt).png
# D:\Dropbox (GaTech)\vaporwave\256x256png\&lt;y83rpx_14 - (jrdsctt).png
# D:\Dropbox (GaTech)\vaporwave\256x256png\&lt;y83rpx_15 - (jrdsctt).png
# D:\Dropbox (GaTech)\vaporwave\256x256png\&lt;y83rpx_16 - (jrdsctt).png
# D:\Dropbox (GaTech)\vaporwave\256x256png\&lt;y83rpx_17 - (jrdsctt).png
# D:\Dropbox (GaTech)\vaporwave\256x256png\&lt;y83rpx_18 - (jrdsctt).png
# D:\Dropbox (GaTech)\vaporwave\256x256png\&lt;y83rpx_19 - (jrdsctt).png
# D:\Dropbox (GaTech)\vaporwave\256x256png\&lt;y83rpx_20 - (jrdsctt).png
# D:\Dropbox (GaTech)\vaporwave\256x256png\&lt;y83rpx_21 - (jrdsctt).png
# D:\Dropbox (GaTech)\vaporwave\256x256png\&lt;y83rpx_22 - (jrdsctt).png
# D:\Dropbox (GaTech)\vaporwave\256x256png\&lt;y83rpx_23 - (jrdsctt).png
# D:\Dropbox (GaTech)\vaporwave\256x256png\&lt;y83rpx_24 - (jrdsctt).png
# D:\Dropbox (GaTech)\vaporwave\256x256png\&lt;y83rpx_25 (from the archives) - (jrdsctt).png
# D:\Dropbox (GaTech)\vaporwave\256x256png\&lt;y83rpx_27 - (jrdsctt).png
# D:\Dropbox (GaTech)\vaporwave\256x256png\&lt;y83rpx_28 - (jrdsctt).png
# D:\Dropbox (GaTech)\vaporwave\256x256png\&lt;y83rpx_29 - (jrdsctt).png
# D:\Dropbox (GaTech)\vaporwave\256x256png\&lt;y83rpx_30 - (jrdsctt).png
# D:\Dropbox (GaTech)\vaporwave\256x256png\&lt;y83rpx_31 - (jrdsctt).png
# D:\Dropbox (GaTech)\vaporwave\256x256png\&lt;__what_ a (lovely) .day__&gt; - (yung_haole).png
# D:\Dropbox (GaTech)\vaporwave\256x256png\' I L L U S I O N ' by me. [this actually began as a squashed pumpkin, or more specifically, a kicked-in jack-o'-lantern.] - (togepitothemax).png
# D:\Dropbox (GaTech)\vaporwave\256x256png\' _ a e s t h e t i c `' - (drop_trout).png
# D:\Dropbox (GaTech)\vaporwave\256x256png\'artboards' - original design - (channel_select).png
# D:\Dropbox (GaTech)\vaporwave\256x256png\'Blast off from the mountains' - (BlankSector).png
# D:\Dropbox (GaTech)\vaporwave\256x256png\'Falling' T-shirt by Nano Designs 95 - Available now in Black and White!!! (Link in comments) - (nanodesigns_95).png
# D:\Dropbox (GaTech)\vaporwave\256x256png\'FLASH Magazine_ Mock Magazine Cover - (cheyrrcherry).png
# D:\Dropbox (GaTech)\vaporwave\256x256png\'Friends' - (danhab99).png
# D:\Dropbox (GaTech)\vaporwave\256x256png\'In a rich man's house, there is no place to spit but his face' - Diogenes - (Everything4Everyone).png
# D:\Dropbox (GaTech)\vaporwave\256x256png\'Leisure Suite' - (vaporoptics).png
# D:\Dropbox (GaTech)\vaporwave\256x256png\'STR-001_ Stormy Valley', Aerosol on Canvas by me - (zudzen).png
# D:\Dropbox (GaTech)\vaporwave\256x256png\'STR-003_ Grey Area' by me, Aerosol_Acrylic on 10 x 8_ Canvas - (zudzen).png
# D:\Dropbox (GaTech)\vaporwave\256x256png\'STR-004_ Framed Obsolescence' by me (zudzen), Aerosol_Acrylic on 10 x 8_ - (zudzen)-1.png
# D:\Dropbox (GaTech)\vaporwave\256x256png\'STR-004_ Framed Obsolescence' by me (zudzen), Aerosol_Acrylic on 10 x 8_ - (zudzen)-2.png
# D:\Dropbox (GaTech)\vaporwave\256x256png\'STR-005_ The Algorithm' by me, Aerosol_Acrylic on 10 x 8_ Canvas - (zudzen).png
# D:\Dropbox (GaTech)\vaporwave\256x256png\'STR-013_ Whole New World', Aerosol &amp; Acrylic on 12 x 12_ Panel - (zudzen).png
# D:\Dropbox (GaTech)\vaporwave\256x256png\'Technical Difficulties' - (Son_of_Surtur).png
# D:\Dropbox (GaTech)\vaporwave\256x256png\'Traveling to the unknown' is the perfect description for this beat - (DevideBeats).png
# D:\Dropbox (GaTech)\vaporwave\256x256png\'Weathering with you' - (domsky23).png
# D:\Dropbox (GaTech)\vaporwave\256x256png\'𝐃𝐔𝐑𝐈𝐍𝐆 𝐓𝐇𝐄 𝐖𝐀𝐑, 𝟐 𝟎 𝟎 𝟏' - (DannyDyerAbridged).png
# D:\Dropbox (GaTech)\vaporwave\256x256png\'𝓢𝓲𝓵𝓮𝓷𝓬𝓮' - 40 𝓜𝓲𝓷𝓾𝓽𝓮𝓼 𝓛𝓸𝓯𝓲 𝓗𝓲𝓹 𝓗𝓸𝓹 𝓜𝓲𝔁 - (DevideBeats).png
# D:\Dropbox (GaTech)\vaporwave\256x256png\'︿' - (VHS-CAT).png
# D:\Dropbox (GaTech)\vaporwave\256x256png\( B L E S S E D ) -- Pop Art x Vaporwave Crossover - (derpfaced).png
# D:\Dropbox (GaTech)\vaporwave\256x256png\( n u l l ) - (honeypowered) - 2.png
# D:\Dropbox (GaTech)\vaporwave\256x256png\( n u l l ) - (honeypowered).png
# D:\Dropbox (GaTech)\vaporwave\256x256png\( ^ _ m e l e e w a v e _ ^ ) - (klttles).png
# D:\Dropbox (GaTech)\vaporwave\256x256png\( __ Oh Machine! __ ) (2015) _ [Shadeprint] - (Shadeprint).png
# D:\Dropbox (GaTech)\vaporwave\256x256png\( ͡° ͜ʖ ͡°) V A P O R T O D D ( ͡° ͜ʖ ͡°) - (Deleted).png
# D:\Dropbox (GaTech)\vaporwave\256x256png\(ab)Normal - Dichtelust - (SwimmingAirplane).png
# D:\Dropbox (GaTech)\vaporwave\256x256png\(Anime) My First A T T E M P T (Golden Boy) - (MellowDinosaur).png
# D:\Dropbox (GaTech)\vaporwave\256x256png\(another) Vaporwave-inspired painting at NYC gallery - (CereusMax).png
# D:\Dropbox (GaTech)\vaporwave\256x256png\(Art I made for some furry) - (NewbzCool).png
# D:\Dropbox (GaTech)\vaporwave\256x256png\(Art not mine, text scroll is) Man does this ever look natural on a CRT - (GDZippN).png
# D:\Dropbox (GaTech)\vaporwave\256x256png\(first time doing vaporwave art)ｗｈｅｒｅ ａｒｅ ｙｏｕ？ - (BasicallySebastian).png
# D:\Dropbox (GaTech)\vaporwave\256x256png\(g)host (collage) - (chema64).png
# D:\Dropbox (GaTech)\vaporwave\256x256png\(it's my first post here, sorry) Thought someone might get interested in my work - (Deleted).png
# D:\Dropbox (GaTech)\vaporwave\256x256png\(label) __ made via vsco distortia &amp; photoshop - (tymcgo).png
# D:\Dropbox (GaTech)\vaporwave\256x256png\(made by myself) It's something like a cover for one of my unreleased tracks - (cashcartibichh).png
# D:\Dropbox (GaTech)\vaporwave\256x256png\(My artwork) @M1lo.sinned Instagram - (MyNansMyDad).png
# D:\Dropbox (GaTech)\vaporwave\256x256png\(Not mine) Here's the Dream Catalogue background from the NTS Radio show a few days back - (kotmon).png
# D:\Dropbox (GaTech)\vaporwave\256x256png\(OC) (DARKERWAVE) - (Davybomb).png
# D:\Dropbox (GaTech)\vaporwave\256x256png\(oc) - (Adleemus).png
# D:\Dropbox (GaTech)\vaporwave\256x256png\(OC) Aeroglyph - tried to go for a 'quintessential vaporwave' look - (sunmachine_).png
# D:\Dropbox (GaTech)\vaporwave\256x256png\(OC) I like to make vapourwave that has a modern vibe, what do you think_ - (Binch101).png
# D:\Dropbox (GaTech)\vaporwave\256x256png\(OC) night time plaza - (rowie324).png
# D:\Dropbox (GaTech)\vaporwave\256x256png\(OC) Polar Paradise - (hman1025).png
# D:\Dropbox (GaTech)\vaporwave\256x256png\(OC) S N A Z Z Y - (Davybomb).png
# D:\Dropbox (GaTech)\vaporwave\256x256png\(oc) Song is T.I.M.E part 2 by Emil Rottmayer - (Mikhail_B_Art).png
# D:\Dropbox (GaTech)\vaporwave\256x256png\(OC) This is more glitch art-y, but I think it belonged here in it's own merit - (Upshft).png
# D:\Dropbox (GaTech)\vaporwave\256x256png\(OC) Three Variations on a Theme - (lexdaily)-1.png
# D:\Dropbox (GaTech)\vaporwave\256x256png\(OC) Three Variations on a Theme - (lexdaily)-2.png
# D:\Dropbox (GaTech)\vaporwave\256x256png\(OC) Three Variations on a Theme - (lexdaily)-3.png
# D:\Dropbox (GaTech)\vaporwave\256x256png\(OC) V H S W A V E - (newavenewtype).png
# D:\Dropbox (GaTech)\vaporwave\256x256png\(OC) Ａｎｇｅｌ Ｃｏｒｐ． ン依ノ (Criticism welcome!) - (Binch101).png
# D:\Dropbox (GaTech)\vaporwave\256x256png\(Pool Works 1) - (Manila-Automat).png
# D:\Dropbox (GaTech)\vaporwave\256x256png\(Queen) - (we300men).png
# D:\Dropbox (GaTech)\vaporwave\256x256png\(sunset seduces __ the horizon flees ) - (datastain).png
# D:\Dropbox (GaTech)\vaporwave\256x256png\(VIDEO) VAPERROR - Mana Pool ALBUM REVIEW _ Check out my latest video! - (Pad-Chennington).png
# D:\Dropbox (GaTech)\vaporwave\256x256png\(WARNING- AESTHETIC) - (Deleted).png
# D:\Dropbox (GaTech)\vaporwave\256x256png\(x-post from _r_vaporwave) Cleaned-up version of the _Wave of the Future_ poster - (Deleted)-1.png
# D:\Dropbox (GaTech)\vaporwave\256x256png\(x-post r_fakealbumcovers) F R A C T U R E - (hman1025).png
# D:\Dropbox (GaTech)\vaporwave\256x256png\(_ - (miss-_-fortunate).png
# D:\Dropbox (GaTech)\vaporwave\256x256png\(´༎ຶོρ༎ຶོ`) c L i p P y iDontFeelSoGood ~ - (domigucci).png
# D:\Dropbox (GaTech)\vaporwave\256x256png\(っ◔◡◔)っ ♥ HYGF ♥ - (IanCharlesOfficial).png
# D:\Dropbox (GaTech)\vaporwave\256x256png\(無處) - (OnlineSoupMan).png
# D:\Dropbox (GaTech)\vaporwave\256x256png\)_ It's derivative, but is my first time _( - (Slaver117).png
# D:\Dropbox (GaTech)\vaporwave\256x256png\+ m i d i + - (ruacanobeef).png
# D:\Dropbox (GaTech)\vaporwave\256x256png\++___64(2) - (SadCreative).png
# D:\Dropbox (GaTech)\vaporwave\256x256png\+ʜᴇʟɪᴏs_²⁰²²© - (quadre420).png
# D:\Dropbox (GaTech)\vaporwave\256x256png\, - (Mnjaaaau).png
# D:\Dropbox (GaTech)\vaporwave\256x256png\, god, - (haurgh).png
# D:\Dropbox (GaTech)\vaporwave\256x256png\- - (diskette1).png
# D:\Dropbox (GaTech)\vaporwave\256x256png\- - - g l i t c h e d ___ - (Deleted).png
# D:\Dropbox (GaTech)\vaporwave\256x256png\- 2 - - (kelvin9595).png
# D:\Dropbox (GaTech)\vaporwave\256x256png\- d r e a m i n g - credits_ me [insta 🔥 angery_dany_98] - (schirrudan).png
# D:\Dropbox (GaTech)\vaporwave\256x256png\- n o t i t l e - - (normalouise).png
# D:\Dropbox (GaTech)\vaporwave\256x256png\- w h a d d u p - - (Seph-Raz).png
# D:\Dropbox (GaTech)\vaporwave\256x256png\- フラットメイト - - (ToastScience).png
# D:\Dropbox (GaTech)\vaporwave\256x256png\-- - (drop_trout).png
# D:\Dropbox (GaTech)\vaporwave\256x256png\-- 3 -- e a s y -- p a y m e n t s -- - (artrock0).png
# D:\Dropbox (GaTech)\vaporwave\256x256png\-- j u m p s t a r t -- - (normalouise).png
# D:\Dropbox (GaTech)\vaporwave\256x256png\-- ＡＥＳＴＨＥＴＩＣ WINDOWS - (IwillNoFapuntildeath).png
# D:\Dropbox (GaTech)\vaporwave\256x256png\---3--- E A S Y--- P A Y M E N T S--- - (artrock0).png
# D:\Dropbox (GaTech)\vaporwave\256x256png\-forgotten- ink.13.17 - (avidya1997).png
# D:\Dropbox (GaTech)\vaporwave\256x256png\-l-l-l- - (VCCOV).png
# D:\Dropbox (GaTech)\vaporwave\256x256png\-s-u-c-k- .png - (hex-a-decimal).png
# D:\Dropbox (GaTech)\vaporwave\256x256png\-Swish- - (eloquent_erection).png
# D:\Dropbox (GaTech)\vaporwave\256x256png\-ᴩʀᴏᴊᴇᴄᴛ-ᴄᴏʟʟᴀɢᴇ- - (seth_startix).png
# D:\Dropbox (GaTech)\vaporwave\256x256png\-﻿Ｓａｖｉｏｕｒ- - (evawsonsimp).png
# D:\Dropbox (GaTech)\vaporwave\256x256png\000000_whole_01 - (jrdsctt).png
# D:\Dropbox (GaTech)\vaporwave\256x256png\000117 - (jebbsbushes).png
# D:\Dropbox (GaTech)\vaporwave\256x256png\00070p0kki - (ghostaccount1306).png
# D:\Dropbox (GaTech)\vaporwave\256x256png\00_05 - (Nothinginator).png
# D:\Dropbox (GaTech)\vaporwave\256x256png\00_44 [OC] - (dankmattur).png
# D:\Dropbox (GaTech)\vaporwave\256x256png\01 - (luigipica).png
# D:\Dropbox (GaTech)\vaporwave\256x256png\01 cybernetic (18 carat affair) - (glompix).png
# D:\Dropbox (GaTech)\vaporwave\256x256png\01101101 01111001 00100000 01101000 01100101 01100001 01110010 01110100 00100000 01101100 01101001 01100101 01110011 00100000 01 - (BoilingKettle).png
# D:\Dropbox (GaTech)\vaporwave\256x256png\01L - (destroit1387).png
# D:\Dropbox (GaTech)\vaporwave\256x256png\02 - (freecslol).png
# D:\Dropbox (GaTech)\vaporwave\256x256png\0ne_choic3_error1ng.exe - (k_1c).png
# D:\Dropbox (GaTech)\vaporwave\256x256png\0pr42 - (crackhead781).png
# D:\Dropbox (GaTech)\vaporwave\256x256png\0PRUN - (crackhead781).png
# D:\Dropbox (GaTech)\vaporwave\256x256png\0S4K4 - (4RT1UZ).png
# D:\Dropbox (GaTech)\vaporwave\256x256png\0xFF - (Deleted).png
# D:\Dropbox (GaTech)\vaporwave\256x256png\0xFFFF - (EatAllTheWaffles).png
# D:\Dropbox (GaTech)\vaporwave\256x256png\1 - (Xion-Lolmod).png
# D:\Dropbox (GaTech)\vaporwave\256x256png\1 0 0 1 1 1 - (LiveLikeAKingpin).png
# D:\Dropbox (GaTech)\vaporwave\256x256png\1 9 8 9 - (Deleted) - 2.png
# D:\Dropbox (GaTech)\vaporwave\256x256png\1 9 8 9 - (Deleted).png
# D:\Dropbox (GaTech)\vaporwave\256x256png\1 9 8 9 - (versacepuppylobster).png
# D:\Dropbox (GaTech)\vaporwave\256x256png\1 L I F E L E F T - 東京 - (epiccookiejar).png
# D:\Dropbox (GaTech)\vaporwave\256x256png\1 year ago today, I posted my first ever vaporwave art to reddit. Here's a remake of my first piece - (midway868).png
# D:\Dropbox (GaTech)\vaporwave\256x256png\1-800-AESTHETICS - (oneandonlymemegod).png
# D:\Dropbox (GaTech)\vaporwave\256x256png\1-800-SADSAD-SAD - (sloggin_toboggan).png
# D:\Dropbox (GaTech)\vaporwave\256x256png\1.png
# D:\Dropbox (GaTech)\vaporwave\256x256png\10 hour mind melt animation(via Terminal Montage on YouTube) - (MadtonyGamingYT).png
# D:\Dropbox (GaTech)\vaporwave\256x256png\10 hour mind melt(via Terminal Montage on YouTube) - (MadtonyGamingYT).png
# D:\Dropbox (GaTech)\vaporwave\256x256png\1030_project H E L I O S - (DopaminQuelle).png
# D:\Dropbox (GaTech)\vaporwave\256x256png\1080p for mobiles. Made from scratch in 4 hours. Hope you like it - (DolphinLord98).png
# D:\Dropbox (GaTech)\vaporwave\256x256png\109_disposable_jazz_solo.gif - (gntrr).png
# D:\Dropbox (GaTech)\vaporwave\256x256png\11 - (Xion-Lolmod).png
# D:\Dropbox (GaTech)\vaporwave\256x256png\13 - INSIGHT - (mottiden).png
# D:\Dropbox (GaTech)\vaporwave\256x256png\1366 x 768 (B E F O R E Y O U G O) - (Bistro_Clancy).png
# D:\Dropbox (GaTech)\vaporwave\256x256png\14.4 Gangsta - (robness).png
# D:\Dropbox (GaTech)\vaporwave\256x256png\14_09_19 edited with picsart - (MattClay11).png
# D:\Dropbox (GaTech)\vaporwave\256x256png\15_5000 戦争が変わった - (somanyanvils).png
# D:\Dropbox (GaTech)\vaporwave\256x256png\18 Carat Affair ~ Promethazine (Music Video) - (DisketteDetective) - 2.png
# D:\Dropbox (GaTech)\vaporwave\256x256png\1980s「バニラ COLA」¥,50 - (invalid95).png
# D:\Dropbox (GaTech)\vaporwave\256x256png\1984 Action Arms brochure advertising the Uzi carbine and pistol [1259x1655] - (olliec420).png
# D:\Dropbox (GaTech)\vaporwave\256x256png\1985 Xbox One S - (hkhunterkiller1984).png
# D:\Dropbox (GaTech)\vaporwave\256x256png\1985carposter.bmp - (hkhunterkiller1984).png
# D:\Dropbox (GaTech)\vaporwave\256x256png\1987 MR2 - (Aw1187).png
# D:\Dropbox (GaTech)\vaporwave\256x256png\1995 Raytrace - (tlacct).png
# D:\Dropbox (GaTech)\vaporwave\256x256png\1995.wav - (Mcdirtie).png
# D:\Dropbox (GaTech)\vaporwave\256x256png\1996.jpg - (neovapor).png
# D:\Dropbox (GaTech)\vaporwave\256x256png\1999 - (oldschooI).png
# D:\Dropbox (GaTech)\vaporwave\256x256png\1st a e s t h e t i c - (Deleted).png
# D:\Dropbox (GaTech)\vaporwave\256x256png\1st Attempt at VAPORWAVE ART. (___FEEDBACK NEEDED___) - (crr147).png
# D:\Dropbox (GaTech)\vaporwave\256x256png\1st attempt in Vaporwave Art - (Nobvious001).png
# D:\Dropbox (GaTech)\vaporwave\256x256png\1st attempt why do you guys think _ - (Opallo).png
# D:\Dropbox (GaTech)\vaporwave\256x256png\1st attempt, please gimme some tips to improve! (also i know the 1st image is too simple) - (Neko_urself)-1.png
# D:\Dropbox (GaTech)\vaporwave\256x256png\1st attempt, please gimme some tips to improve! (also i know the 1st image is too simple) - (Neko_urself)-2.png
# D:\Dropbox (GaTech)\vaporwave\256x256png\1st trial👌👌 - (SalimGoreng).png
# D:\Dropbox (GaTech)\vaporwave\256x256png\1st try - (JaguarrLGND).png
# D:\Dropbox (GaTech)\vaporwave\256x256png\1st try of v a p o r w a v e editing - (Morto400).png
# D:\Dropbox (GaTech)\vaporwave\256x256png\1枚の写真.png - (TheMrFoobles).png
# D:\Dropbox (GaTech)\vaporwave\256x256png\2 (@D4XIS inspired) - (H4ZELXL).png
# D:\Dropbox (GaTech)\vaporwave\256x256png\2 - (Xion-Lolmod).png
# D:\Dropbox (GaTech)\vaporwave\256x256png\2 0 0 0 (IG_ cyber3tr0) - (_____Dan_).png
# D:\Dropbox (GaTech)\vaporwave\256x256png\2 0 0 1 _ 3 - (FoilMythic).png
# D:\Dropbox (GaTech)\vaporwave\256x256png\2 0 0 1 _ 3 [alt] - (FoilMythic).png
# D:\Dropbox (GaTech)\vaporwave\256x256png\2 0 0 1 _ 4 - it's like nothing we've seen before - (FoilMythic).png
# D:\Dropbox (GaTech)\vaporwave\256x256png\2 0 0 1 _ 5 _ second suns - (FoilMythic).png
# D:\Dropbox (GaTech)\vaporwave\256x256png\2 0 0 1_ if you like stuff like this lmk - (FoilMythic).png
# D:\Dropbox (GaTech)\vaporwave\256x256png\2 0 1 6 ~ - (jakeyboii217).png
# D:\Dropbox (GaTech)\vaporwave\256x256png\2 1 6 0 B E A C H W A L K 3 8 4 0 - (dumptherain).png
# D:\Dropbox (GaTech)\vaporwave\256x256png\2 d o w n 2 t o g o - (osmosis_bones).png
# D:\Dropbox (GaTech)\vaporwave\256x256png\2 D __ 2 S O O N - (Deleted).png
# D:\Dropbox (GaTech)\vaporwave\256x256png\2 Diablos, 1 Space - (Prais24).png
# D:\Dropbox (GaTech)\vaporwave\256x256png\2 Fresh - (Gooblemygobble).png
# D:\Dropbox (GaTech)\vaporwave\256x256png\2 Lasers - 2 way mirrors - First Surface Mirrors - Laser Art - (Lew182).png
# D:\Dropbox (GaTech)\vaporwave\256x256png\2 sal lads - (Rodrigo669).png
# D:\Dropbox (GaTech)\vaporwave\256x256png\2.png
# D:\Dropbox (GaTech)\vaporwave\256x256png\2001 Miami Beach - (98aesthetics).png
# D:\Dropbox (GaTech)\vaporwave\256x256png\2006 ファック - (Martiian).png
# D:\Dropbox (GaTech)\vaporwave\256x256png\2012.9.30 - (triplazz).png
# D:\Dropbox (GaTech)\vaporwave\256x256png\2013 tumblr era artwork - (StrwbrryVapeGod).png
# D:\Dropbox (GaTech)\vaporwave\256x256png\2014年10月での孤独な夜に黙想 - (noahhk).png
# D:\Dropbox (GaTech)\vaporwave\256x256png\2015-08-19 7_10PM - (newkleuz).png
# D:\Dropbox (GaTech)\vaporwave\256x256png\2015は、Windows HomeエディションプレミアムEXハイパー戦いトライプロ - (noahhk).png
# D:\Dropbox (GaTech)\vaporwave\256x256png\2021 goals don't text it - (dotmixtape).png
# D:\Dropbox (GaTech)\vaporwave\256x256png\2049 - (Droyk).png
# D:\Dropbox (GaTech)\vaporwave\256x256png\23 ʷᴬᴷᴿ⁻ᵗᵛ - (IanCharlesOfficial).png
# D:\Dropbox (GaTech)\vaporwave\256x256png\24 Hour Market - (theeAVman).png
# D:\Dropbox (GaTech)\vaporwave\256x256png\247 c i n e m a __ mobile wallpaper - (tymcgo).png
# D:\Dropbox (GaTech)\vaporwave\256x256png\247 p i z z a __ iphone wallpaper - (tymcgo).png
# D:\Dropbox (GaTech)\vaporwave\256x256png\256k - (dookieblaster).png
# D:\Dropbox (GaTech)\vaporwave\256x256png\267_365_v_animate from jlitch365 - (jrdsctt).png
# D:\Dropbox (GaTech)\vaporwave\256x256png\2nd attempt - (Lemon_Cola).png
# D:\Dropbox (GaTech)\vaporwave\256x256png\2nd attempt at vaporwave - (oly88).png
# D:\Dropbox (GaTech)\vaporwave\256x256png\2nd OC - mistakes - (huskee_).png
# D:\Dropbox (GaTech)\vaporwave\256x256png\2nd vaporwave-y art i made - (greendaydad).png
# D:\Dropbox (GaTech)\vaporwave\256x256png\2nd work, Opinions_ - (Spacekittehh).png
# D:\Dropbox (GaTech)\vaporwave\256x256png\2▪︎0▪︎1▪︎6 - (Manila-Automat).png
# D:\Dropbox (GaTech)\vaporwave\256x256png\2つずつ - (chema64).png
# D:\Dropbox (GaTech)\vaporwave\256x256png\3 - (Xion-Lolmod).png
# D:\Dropbox (GaTech)\vaporwave\256x256png\3 0 0 0 0 0 - (PonySpawn).png
# D:\Dropbox (GaTech)\vaporwave\256x256png\3 D . W A V _ Works with actual 3d glasses - (heyitschet).png
# D:\Dropbox (GaTech)\vaporwave\256x256png\3 D P R I N T I N G - (billiam22).png
# D:\Dropbox (GaTech)\vaporwave\256x256png\3 Vaporwave art Album cover I did today. I can change the name of the artist for you if you would like to use one of this. I don't make vaperwave myself. - (Therathos)-1.png
# D:\Dropbox (GaTech)\vaporwave\256x256png\3 Vaporwave art Album cover I did today. I can change the name of the artist for you if you would like to use one of this. I don't make vaperwave myself. - (Therathos)-2.png
# D:\Dropbox (GaTech)\vaporwave\256x256png\3 Vaporwave art Album cover I did today. I can change the name of the artist for you if you would like to use one of this. I don't make vaperwave myself. - (Therathos)-3.png
# D:\Dropbox (GaTech)\vaporwave\256x256png\3 Vaporwave Vinyl Records That Must Be Pressed! _ Pad Chennington NEW VIDEO _) - (Pad-Chennington).png
# D:\Dropbox (GaTech)\vaporwave\256x256png\3-Twenty Four (2015) _ [Shadeprint] - (Shadeprint).png
# D:\Dropbox (GaTech)\vaporwave\256x256png\30,000 feet - (somano4).png
# D:\Dropbox (GaTech)\vaporwave\256x256png\328_365_v_animate from jlitch365 - (jrdsctt).png
# D:\Dropbox (GaTech)\vaporwave\256x256png\333 - (destroit1387).png
# D:\Dropbox (GaTech)\vaporwave\256x256png\333342天国 - (Dronevil27).png
# D:\Dropbox (GaTech)\vaporwave\256x256png\3D art by Chad Knight - (supremegalacticgod).png
# D:\Dropbox (GaTech)\vaporwave\256x256png\3D Diorama - (79ebola).png
# D:\Dropbox (GaTech)\vaporwave\256x256png\3D for everyone @YoungMarinara - (Yakulelk).png
# D:\Dropbox (GaTech)\vaporwave\256x256png\3D landscape I made yesterday - (cubedude777).png
# D:\Dropbox (GaTech)\vaporwave\256x256png\3D model _ render - (Fluff-Cheater).png
# D:\Dropbox (GaTech)\vaporwave\256x256png\3D modeled, printed, and painted this Vaporwaveon - (eatlesspoopmore).png
# D:\Dropbox (GaTech)\vaporwave\256x256png\3D Printed Aesthetic - (ClassyGoat).png
# D:\Dropbox (GaTech)\vaporwave\256x256png\3D Printed Porcelain Statue of Helios - (1234qwert).png
# D:\Dropbox (GaTech)\vaporwave\256x256png\3D render of a vaporwave inspired office made in Blender - (elaiosome).png
# D:\Dropbox (GaTech)\vaporwave\256x256png\3d render ~ i n s p i r e d _ b y ~ - (scris101).png
# D:\Dropbox (GaTech)\vaporwave\256x256png\3D scan of my head turned out bad, so I decided to recycle it into vaporwave scene - (hippymule).png
# D:\Dropbox (GaTech)\vaporwave\256x256png\3D Vaporravehead - (beathoveen).png
# D:\Dropbox (GaTech)\vaporwave\256x256png\3d Vaporwave i tried - (Leastham).png
# D:\Dropbox (GaTech)\vaporwave\256x256png\3do - (HotlineBoca).png
# D:\Dropbox (GaTech)\vaporwave\256x256png\3Dチェッカーゲーム95.EXE - (arby233)-1.png
# D:\Dropbox (GaTech)\vaporwave\256x256png\3Dチェッカーゲーム95.EXE - (arby233)-2.png
# D:\Dropbox (GaTech)\vaporwave\256x256png\3Dチェッカーゲーム95.EXE - (arby233)-3.png
# D:\Dropbox (GaTech)\vaporwave\256x256png\3rd rock from the sun - (blunt_action).png
# D:\Dropbox (GaTech)\vaporwave\256x256png\3rd wave - (qvarcos).png
# D:\Dropbox (GaTech)\vaporwave\256x256png\3番目の4.2目 [ your dream here ] - [OC] - i'm altering my own photos into fake album covers. comes with a free mobile wallpaper cos fuck consumerism - (Deleted)-1.png
# D:\Dropbox (GaTech)\vaporwave\256x256png\3番目の4.2目 [ your dream here ] - [OC] - i'm altering my own photos into fake album covers. comes with a free mobile wallpaper cos fuck consumerism - (Deleted)-2.png
# D:\Dropbox (GaTech)\vaporwave\256x256png\4 - (Xion-Lolmod).png
# D:\Dropbox (GaTech)\vaporwave\256x256png\4 0 4 O R I G I N A L I T Y 4 0 4 - (BrothersInGame).png
# D:\Dropbox (GaTech)\vaporwave\256x256png\4 4 4 - (voxen444).png
# D:\Dropbox (GaTech)\vaporwave\256x256png\4 M Y F R I E N D - (Bronx_The_Orangutan).png
# D:\Dropbox (GaTech)\vaporwave\256x256png\4 x 3 club flyer design - (catchvapes).png
# D:\Dropbox (GaTech)\vaporwave\256x256png\404 Memes not found - (Suspicious_fox).png
# D:\Dropbox (GaTech)\vaporwave\256x256png\404_ Ｆａｉｔｈ Ｎｏｔ Ｆｏｕｎｄ - (SheepyTurtle).png
# D:\Dropbox (GaTech)\vaporwave\256x256png\436b27db12b47def69cb54a807144c3b0f815c1a.png
# D:\Dropbox (GaTech)\vaporwave\256x256png\4e0e3d9e497d75fc8f225bb8f208cc6c1964539f.png
# D:\Dropbox (GaTech)\vaporwave\256x256png\4nal0g S4crific3 - (plastic_pyramid).png
# D:\Dropbox (GaTech)\vaporwave\256x256png\4rch3s - (crackhead781).png
# D:\Dropbox (GaTech)\vaporwave\256x256png\4tac0 - OC - (l0tterylisa).png
# D:\Dropbox (GaTech)\vaporwave\256x256png\4_20 - (J4D3G).png
# D:\Dropbox (GaTech)\vaporwave\256x256png\4_U - (CurtisMinks).png
# D:\Dropbox (GaTech)\vaporwave\256x256png\5 - (Xion-Lolmod).png
# D:\Dropbox (GaTech)\vaporwave\256x256png\5 5 5 - (windshadowislanders).png
# D:\Dropbox (GaTech)\vaporwave\256x256png\5 Action News - (day-without-rain).png
# D:\Dropbox (GaTech)\vaporwave\256x256png\5 more minutes - (ButtMunchLoL).png
# D:\Dropbox (GaTech)\vaporwave\256x256png\5 star vaporwave - (jon_targstark).png
# D:\Dropbox (GaTech)\vaporwave\256x256png\540 Air -- Graphical leak of a new release! - (Deleted).png
# D:\Dropbox (GaTech)\vaporwave\256x256png\573 Beach Rally - (neovapor).png
# D:\Dropbox (GaTech)\vaporwave\256x256png\5H4d35.gif - (eightiesmurphy).png
# D:\Dropbox (GaTech)\vaporwave\256x256png\6 - (Xion-Lolmod).png
# D:\Dropbox (GaTech)\vaporwave\256x256png\64 - (ExothermMusic).png
# D:\Dropbox (GaTech)\vaporwave\256x256png\64 D R E A M S - (captancat_baby).png
# D:\Dropbox (GaTech)\vaporwave\256x256png\64++_ - (SadCreative).png
# D:\Dropbox (GaTech)\vaporwave\256x256png\666x666, modeled in Blender, rendered in Bryce - (cheated_in_math).png
# D:\Dropbox (GaTech)\vaporwave\256x256png\6ft= broken heart, this for everyone who can't hug mom today - (TsujSynthmane).png
# D:\Dropbox (GaTech)\vaporwave\256x256png\7 - (Xion-Lolmod).png
# D:\Dropbox (GaTech)\vaporwave\256x256png\7 p.m., Alena Aenami, Digital, 2017 - (Gatord35).png
# D:\Dropbox (GaTech)\vaporwave\256x256png\76 k sq ft - (HotlineBoca).png
# D:\Dropbox (GaTech)\vaporwave\256x256png\7TH AEON __ ANIMATED SHORT FILM - (WolfBluntzer).png
# D:\Dropbox (GaTech)\vaporwave\256x256png\7_-_3 $0___ 0_= ____@___ - (jrdsctt).png
# D:\Dropbox (GaTech)\vaporwave\256x256png\7_-_3 &lt;123@710___ 0_= @_)@____ - (jrdsctt).png
# D:\Dropbox (GaTech)\vaporwave\256x256png\8 - (Xion-Lolmod) - 2.png
# D:\Dropbox (GaTech)\vaporwave\256x256png\8 - (Xion-Lolmod).png
# D:\Dropbox (GaTech)\vaporwave\256x256png\8 B I T - (jelly_ni-).png
# D:\Dropbox (GaTech)\vaporwave\256x256png\80's BMW - (CreamyLeemur).png
# D:\Dropbox (GaTech)\vaporwave\256x256png\80's Music Video Tribute - (SaucyFelipo).png
# D:\Dropbox (GaTech)\vaporwave\256x256png\80's themed. does this work well in your opinion_ - (PolymathicPolemicist).png
# D:\Dropbox (GaTech)\vaporwave\256x256png\80's Trees - (Droyk).png
# D:\Dropbox (GaTech)\vaporwave\256x256png\80's Tropical - (Droyk).png
# D:\Dropbox (GaTech)\vaporwave\256x256png\80s inspiration - (allthingsvr).png
# D:\Dropbox (GaTech)\vaporwave\256x256png\80s vv a v e - (_king_in_the_north).png
# D:\Dropbox (GaTech)\vaporwave\256x256png\80s_Vaporwave based design made by me insta _ eyeworks_ - (Donutlover3000).png
# D:\Dropbox (GaTech)\vaporwave\256x256png\80’s Night club made in Dreams - (Deleted).png
# D:\Dropbox (GaTech)\vaporwave\256x256png\84 olympics - (ghostaccount1306).png
# D:\Dropbox (GaTech)\vaporwave\256x256png\86 infinity_ Future home for vaporwave musical artists on YouTube and art page with eventual merchandise - (86infinity).png
# D:\Dropbox (GaTech)\vaporwave\256x256png\8bit Ａ Ｅ Ｓ Ｔ Ｈ Ｅ Ｔ Ｉ Ｃ Ｓ - (leonneon__).png
# D:\Dropbox (GaTech)\vaporwave\256x256png\9 - (Xion-Lolmod) - 3.png
# D:\Dropbox (GaTech)\vaporwave\256x256png\9 - (Xion-Lolmod).png
# D:\Dropbox (GaTech)\vaporwave\256x256png\9-1-1 EMERGENCY - (DJBaphomet).png
# D:\Dropbox (GaTech)\vaporwave\256x256png\90s aesthetics - (coryharris0715).png
# D:\Dropbox (GaTech)\vaporwave\256x256png\90s computer aesthetic - (wanderer92).png
# D:\Dropbox (GaTech)\vaporwave\256x256png\90s papercup anyone__ Follow me at @caspercasanova _) - (caspercasanova).png
# D:\Dropbox (GaTech)\vaporwave\256x256png\90sFlav - Ｃａｌｌ ｍｅ - (gabrielpsp).png
# D:\Dropbox (GaTech)\vaporwave\256x256png\95 A.D - (FedExFacto).png
# D:\Dropbox (GaTech)\vaporwave\256x256png\95 by 95 Unlimited Enterprises - (SwimmingWater4).png
# D:\Dropbox (GaTech)\vaporwave\256x256png\95 screensaver - (radVHS).png
# D:\Dropbox (GaTech)\vaporwave\256x256png\98.9 KLRU SLO JAMZ - (Deleted).png
# D:\Dropbox (GaTech)\vaporwave\256x256png\99 - (Lemon_Cola).png
# D:\Dropbox (GaTech)\vaporwave\256x256png\; - (pratapbb1).png
# D:\Dropbox (GaTech)\vaporwave\256x256png\;) - (jakeyboii217).png
# D:\Dropbox (GaTech)\vaporwave\256x256png\= N O C T U R N A L = .....Was told this belonged here - (dylans41).png
# D:\Dropbox (GaTech)\vaporwave\256x256png\=!= ホーム ＴＥＲＭＩＮＡＬ 3Ｄ レンダリング =!= - (Toomykins).png
# D:\Dropbox (GaTech)\vaporwave\256x256png\@&lt;t1__3_01 - (jrdsctt).png
# D:\Dropbox (GaTech)\vaporwave\256x256png\@dharma_collage Instagram - (dharma92).png
# D:\Dropbox (GaTech)\vaporwave\256x256png\@kenzoart_ on Instagram is really talented - (rykochristie).png
# D:\Dropbox (GaTech)\vaporwave\256x256png\@neonsaltwater - (neonsaltwater).png
# D:\Dropbox (GaTech)\vaporwave\256x256png\@neonsaltwater desert spa inspired by this song https___m.youtube.com_watch_v=-gAIkNZlj6s&amp;list=PLVMxKqNU8ywKArHBIeKqLxkPcNjs - (neonsaltwater).png
# D:\Dropbox (GaTech)\vaporwave\256x256png\@neonsaltwater https___www.instagram.com_p_B-1Bms2Adbm__igshid=1e1vvz27g56i3 - (neonsaltwater).png
# D:\Dropbox (GaTech)\vaporwave\256x256png\@WowItsRG VaporWave Style - (neighborgang).png
# D:\Dropbox (GaTech)\vaporwave\256x256png\@znicolaou on Instagram - (asanti0).png
# D:\Dropbox (GaTech)\vaporwave\256x256png\A 3D_VR vaporware template I created on www.kokowa.co - (lemuria19).png
# D:\Dropbox (GaTech)\vaporwave\256x256png\A 90's kid nightmare - (BlackMagicChart).png
# D:\Dropbox (GaTech)\vaporwave\256x256png\A 959 kicks up some D I R T - (TehK20ALover).png
# D:\Dropbox (GaTech)\vaporwave\256x256png\A B A N D O N E D F O O D C O U R T - (Dayvallenphotography).png
# D:\Dropbox (GaTech)\vaporwave\256x256png\A B A N D O N M E N T.jpg (oc) - (VBS_Official).png
# D:\Dropbox (GaTech)\vaporwave\256x256png\A B O L I S H W O R K - (Pixelator2033).png
# D:\Dropbox (GaTech)\vaporwave\256x256png\A B O R E A L - (tagowar).png
# D:\Dropbox (GaTech)\vaporwave\256x256png\A B S O L U T E _ W A T E R Z O N E _ 1 9 9 2 - (jamieusrowlando).png
# D:\Dropbox (GaTech)\vaporwave\256x256png\a b s t r a c t - (River_the_Raven).png
# D:\Dropbox (GaTech)\vaporwave\256x256png\a b s u r d i s m - (normalouise).png
# D:\Dropbox (GaTech)\vaporwave\256x256png\A Back-alley - (Droyk).png
# D:\Dropbox (GaTech)\vaporwave\256x256png\A barren landscape - (Notgnirracen).png
# D:\Dropbox (GaTech)\vaporwave\256x256png\A Beautiful Morning - (blair96).png
# D:\Dropbox (GaTech)\vaporwave\256x256png\A Billboarding texture for a relic in my vaporwave roguelite game - (miimii1205).png
# D:\Dropbox (GaTech)\vaporwave\256x256png\A bit ago - (J4D3G).png
# D:\Dropbox (GaTech)\vaporwave\256x256png\A bit of a rough edit, and it ain’t too flashy, but I feel that it really hits that aesthetic while maintaining simplicit - (Incomplete-Degenerat).png
# D:\Dropbox (GaTech)\vaporwave\256x256png\A blender scene I made C&amp;C welcome! _) - (Casimir40K).png
# D:\Dropbox (GaTech)\vaporwave\256x256png\A blood mall (weapon shop for a vaporwave roguelite I'm making) - (miimii1205).png
# D:\Dropbox (GaTech)\vaporwave\256x256png\A bomb about to be blown... That dude is gonna have the time of his life - (miimii1205).png
# D:\Dropbox (GaTech)\vaporwave\256x256png\A Brazilian guy and Yusuke in Buenos Aires - (gcmn2000).png
# D:\Dropbox (GaTech)\vaporwave\256x256png\A build I did for the arcade bar Abari in Charlotte NC - (8L30).png
# D:\Dropbox (GaTech)\vaporwave\256x256png\A building in New Orleans [OC] - (kotonoshi).png
# D:\Dropbox (GaTech)\vaporwave\256x256png\A C Q U I T - (yung_teabag).png
# D:\Dropbox (GaTech)\vaporwave\256x256png\A C T I Ö N-F L I C K by yours truly - (jelly_ni-).png
# D:\Dropbox (GaTech)\vaporwave\256x256png\A C T L I K E Y O U D O N ' T K N O W - (yung_teabag).png
# D:\Dropbox (GaTech)\vaporwave\256x256png\A capture of the Soda City Funk Video I took - (Daydream_Ghost).png
# D:\Dropbox (GaTech)\vaporwave\256x256png\A car sale_ - (SOFA_2080).png
# D:\Dropbox (GaTech)\vaporwave\256x256png\A Christmas painting at the gallery, 12_ x 12_ - (Searchinmano).png
# D:\Dropbox (GaTech)\vaporwave\256x256png\A City Beneath a City ⚙️ Art from a little game I'm working on - (butnotexactly).png
# D:\Dropbox (GaTech)\vaporwave\256x256png\a classic piece of vaporwave art - (lady_dont_be_shady).png
# D:\Dropbox (GaTech)\vaporwave\256x256png\A classic remade in ｈｉｇｈ ｄｅｆｉｎｉｔｉｏｎ - (HeySellers).png
# D:\Dropbox (GaTech)\vaporwave\256x256png\A closer look at the playlist notifications for the vapor game I'm making - (miimii1205).png
# D:\Dropbox (GaTech)\vaporwave\256x256png\A cold life in Irondequoit Bay - (bandaid_bandit).png
# D:\Dropbox (GaTech)\vaporwave\256x256png\A collection of minimal, aesthetic designs - (Dankhis_Khan)-1.png
# D:\Dropbox (GaTech)\vaporwave\256x256png\A collection of minimal, aesthetic designs - (Dankhis_Khan)-2.png
# D:\Dropbox (GaTech)\vaporwave\256x256png\A collection of minimal, aesthetic designs - (Dankhis_Khan)-3.png
# D:\Dropbox (GaTech)\vaporwave\256x256png\A collection of minimal, aesthetic designs - (Dankhis_Khan)-4.png
# D:\Dropbox (GaTech)\vaporwave\256x256png\A collection of minimal, aesthetic designs - (Dankhis_Khan)-5.png
# D:\Dropbox (GaTech)\vaporwave\256x256png\A collection of minimal, aesthetic designs - (Dankhis_Khan)-6.png
# D:\Dropbox (GaTech)\vaporwave\256x256png\A collection of minimal, aesthetic designs - (Dankhis_Khan)-7.png
# D:\Dropbox (GaTech)\vaporwave\256x256png\A collection of minimal, aesthetic designs - (Dankhis_Khan)-8.png
# D:\Dropbox (GaTech)\vaporwave\256x256png\A collection of the vapourware work I've made so far_ - (BlankSector)-01.png
# D:\Dropbox (GaTech)\vaporwave\256x256png\A collection of the vapourware work I've made so far_ - (BlankSector)-02.png
# D:\Dropbox (GaTech)\vaporwave\256x256png\A collection of the vapourware work I've made so far_ - (BlankSector)-03.png
# D:\Dropbox (GaTech)\vaporwave\256x256png\A collection of the vapourware work I've made so far_ - (BlankSector)-04.png
# D:\Dropbox (GaTech)\vaporwave\256x256png\A collection of the vapourware work I've made so far_ - (BlankSector)-05.png
# D:\Dropbox (GaTech)\vaporwave\256x256png\A collection of the vapourware work I've made so far_ - (BlankSector)-06.png
# D:\Dropbox (GaTech)\vaporwave\256x256png\A collection of the vapourware work I've made so far_ - (BlankSector)-07.png
# D:\Dropbox (GaTech)\vaporwave\256x256png\A collection of the vapourware work I've made so far_ - (BlankSector)-08.png
# D:\Dropbox (GaTech)\vaporwave\256x256png\A collection of the vapourware work I've made so far_ - (BlankSector)-09.png
# D:\Dropbox (GaTech)\vaporwave\256x256png\A collection of the vapourware work I've made so far_ - (BlankSector)-10.png
# D:\Dropbox (GaTech)\vaporwave\256x256png\A collection of the vapourware work I've made so far_ - (BlankSector)-11.png
# D:\Dropbox (GaTech)\vaporwave\256x256png\A collection of the vapourware work I've made so far_ - (BlankSector)-12.png
# D:\Dropbox (GaTech)\vaporwave\256x256png\A collection of the vapourware work I've made so far_ - (BlankSector)-13.png
# D:\Dropbox (GaTech)\vaporwave\256x256png\A collection of the vapourware work I've made so far_ - (BlankSector)-14.png
# D:\Dropbox (GaTech)\vaporwave\256x256png\A collection of the vapourware work I've made so far_ - (BlankSector)-15.png
# D:\Dropbox (GaTech)\vaporwave\256x256png\A collection of the vapourware work I've made so far_ - (BlankSector)-16.png
# D:\Dropbox (GaTech)\vaporwave\256x256png\A collection of the vapourware work I've made so far_ - (BlankSector)-17.png
# D:\Dropbox (GaTech)\vaporwave\256x256png\A color-by-number I finished recently, I call it 'Abandoned' - (-viktorssister-).jpg.png
# D:\Dropbox (GaTech)\vaporwave\256x256png\A color-by-number I finished recently, I call it 'Abandoned' - (-viktorssister-).png
# D:\Dropbox (GaTech)\vaporwave\256x256png\A commission I made for a friend. Tought you guys could enjoy - (borgolomor).png
# D:\Dropbox (GaTech)\vaporwave\256x256png\A compilation of my year's art_ - (SebbyGet4).png
# D:\Dropbox (GaTech)\vaporwave\256x256png\A Completely Custom War Aesthetic! - (BigDealRahil).png
# D:\Dropbox (GaTech)\vaporwave\256x256png\A concept album cover I made - (DownIsNotCrouch).png
# D:\Dropbox (GaTech)\vaporwave\256x256png\A couple hours of eerie, ethereal, haunting music. Enjoy! - (passoskrishna).png
# D:\Dropbox (GaTech)\vaporwave\256x256png\A cover I made for a garage rock band Noise complaint who wanted a vapor style cover. This was my first attempt at making vapor art - (PoulwithAnO).png
# D:\Dropbox (GaTech)\vaporwave\256x256png\A cover I made for an album I'm working on - (DPooly1996).png
# D:\Dropbox (GaTech)\vaporwave\256x256png\a crappy phone wallpaper __ looks best with smartlauncher - (normalouise).png
# D:\Dropbox (GaTech)\vaporwave\256x256png\A cute edit I made, for a “new” movement where I’m from #cannawavepr - (spacenoire).png
# D:\Dropbox (GaTech)\vaporwave\256x256png\A D I D A S A E S T H E T I C S - (0b1_juan_ken0b1).png
# D:\Dropbox (GaTech)\vaporwave\256x256png\A D I D A S ® - (TheHappyWizard).png
# D:\Dropbox (GaTech)\vaporwave\256x256png\A D O B E - (OBLIMINON).png
# D:\Dropbox (GaTech)\vaporwave\256x256png\a d r i f t - (jakeyboii217).png
# D:\Dropbox (GaTech)\vaporwave\256x256png\a d v e n t u r e very much deep - (actuallynoire).png
# D:\Dropbox (GaTech)\vaporwave\256x256png\A David render, by me - (SpicyMemeB0i).png
# D:\Dropbox (GaTech)\vaporwave\256x256png\A deep feeling_ Art by me - (NewbzCool).png
# D:\Dropbox (GaTech)\vaporwave\256x256png\A desktop background I put together at 3am - (jayhawkfilm).png
# D:\Dropbox (GaTech)\vaporwave\256x256png\A different title - (kaniwo).png
# D:\Dropbox (GaTech)\vaporwave\256x256png\A distraction from the anxiety - (djpacheco1003).png
# D:\Dropbox (GaTech)\vaporwave\256x256png\A drawing I did in Sketch - based on a Hiroshi Nagai painting - (yunghegemony).png
# D:\Dropbox (GaTech)\vaporwave\256x256png\A drawing i made and i edited it! - (Mysteriousdudes).png
# D:\Dropbox (GaTech)\vaporwave\256x256png\a drawing i made to accompany B__ Start Up by BB - (bfant_art).png
# D:\Dropbox (GaTech)\vaporwave\256x256png\a drawing of grandpa's tape recorder - (wavycrisis).png
# D:\Dropbox (GaTech)\vaporwave\256x256png\A E R O - (GameHuskyDev).png
# D:\Dropbox (GaTech)\vaporwave\256x256png\A E R O B I C S - (seth_startix).png
# D:\Dropbox (GaTech)\vaporwave\256x256png\A E S T H E T I C &gt; L I F E - (skyfucker6).png
# D:\Dropbox (GaTech)\vaporwave\256x256png\A E S T H E T I C - (Aesthetic_Blink).png
# D:\Dropbox (GaTech)\vaporwave\256x256png\A E S T H E T I C - (a_person_96).png
# D:\Dropbox (GaTech)\vaporwave\256x256png\A E S T H E T I C - (Deleted).png
# D:\Dropbox (GaTech)\vaporwave\256x256png\a e s t h e t i c - (EnlightenedGreen) - 2.png
# D:\Dropbox (GaTech)\vaporwave\256x256png\a e s t h e t i c - (EnlightenedGreen) - 3.png
# D:\Dropbox (GaTech)\vaporwave\256x256png\a e s t h e t i c - (EnlightenedGreen).png
# D:\Dropbox (GaTech)\vaporwave\256x256png\a e s t h e t i c - (hmochoa95).png
# D:\Dropbox (GaTech)\vaporwave\256x256png\A E S T H E T I C - (Joshtom333).png
# D:\Dropbox (GaTech)\vaporwave\256x256png\A e s t h e t i c - (LucasSpira).png
# D:\Dropbox (GaTech)\vaporwave\256x256png\a e s t h e t i c - (macmoosie).png
# D:\Dropbox (GaTech)\vaporwave\256x256png\A E S T H E T I C - (mattc90).png
# D:\Dropbox (GaTech)\vaporwave\256x256png\a e s t h e t i c - (NVPK1NS).png
# D:\Dropbox (GaTech)\vaporwave\256x256png\A E S T H E T I C - (supercfj).png
# D:\Dropbox (GaTech)\vaporwave\256x256png\A E S T H E T I C - (Thereal60Kc).png
# D:\Dropbox (GaTech)\vaporwave\256x256png\A E S T H E T I C - (TheWilde1).png
# D:\Dropbox (GaTech)\vaporwave\256x256png\A E S T H E T I C - (_jurassicapark).png
# D:\Dropbox (GaTech)\vaporwave\256x256png\A E S T H E T I C - Tribute to KIMBO SLICE - (borthas).png
# D:\Dropbox (GaTech)\vaporwave\256x256png\A E S T H E T I C 1.6 - (moltezzanti).png
# D:\Dropbox (GaTech)\vaporwave\256x256png\A E S T H E T I C A P I T O L - (Zeebuss).png
# D:\Dropbox (GaTech)\vaporwave\256x256png\A e s t h e t i c a t (made by me) - (Ivonnii).png
# D:\Dropbox (GaTech)\vaporwave\256x256png\a e s t h e t i c Art my cousin made. Check out her twitter https___twitter.com_itsyaboiyardee - (wkw4jack).png
# D:\Dropbox (GaTech)\vaporwave\256x256png\A E S T H E T I C at ノットホール村 - (Jlnhlfan).png
# D:\Dropbox (GaTech)\vaporwave\256x256png\a e s t h e t i c b e a u t y f r o m W o r d s E y e . c o m - (Deleted).png
# D:\Dropbox (GaTech)\vaporwave\256x256png\A E S T H E T I C B E E R - (leanagosto13).png
# D:\Dropbox (GaTech)\vaporwave\256x256png\A E S T H E T I C C - (high_priestess23).png
# D:\Dropbox (GaTech)\vaporwave\256x256png\a e s t h e t i c c a r - (Quyix).png
# D:\Dropbox (GaTech)\vaporwave\256x256png\a e s t h e t i c e n d s h e r e - (nolifedeepwoe).png
# D:\Dropbox (GaTech)\vaporwave\256x256png\A E S T H E T I C E X I T - (fried_potat0es).png
# D:\Dropbox (GaTech)\vaporwave\256x256png\A E S T H E T I C F A S H I O N - (dannynewfag).png
# D:\Dropbox (GaTech)\vaporwave\256x256png\A e s t h e t i c Female body (xpost from _r_VaporwaveAesthetics) - (RedditsUnlovedSon).png
# D:\Dropbox (GaTech)\vaporwave\256x256png\A e s t h e t i c H a n d D r y e r - (Mothmanlive).png
# D:\Dropbox (GaTech)\vaporwave\256x256png\a e s t h e t i c j d m (first attempt) - (shminghong).png
# D:\Dropbox (GaTech)\vaporwave\256x256png\a e s t h e t I c mall foodcourt - (Death_has_relaxed_me).png
# D:\Dropbox (GaTech)\vaporwave\256x256png\A E S T H E T I C meme - (jelly_ni-).png
# D:\Dropbox (GaTech)\vaporwave\256x256png\A E S T H E T I C R E A L M - (AaronStraine)-01.png
# D:\Dropbox (GaTech)\vaporwave\256x256png\A E S T H E T I C R E A L M - (AaronStraine)-02.png
# D:\Dropbox (GaTech)\vaporwave\256x256png\A E S T H E T I C R E A L M - (AaronStraine)-03.png
# D:\Dropbox (GaTech)\vaporwave\256x256png\A E S T H E T I C R E A L M - (AaronStraine)-04.png
# D:\Dropbox (GaTech)\vaporwave\256x256png\A E S T H E T I C R E A L M - (AaronStraine)-05.png
# D:\Dropbox (GaTech)\vaporwave\256x256png\A E S T H E T I C R E A L M - (AaronStraine)-06.png
# D:\Dropbox (GaTech)\vaporwave\256x256png\A E S T H E T I C R E A L M - (AaronStraine)-07.png
# D:\Dropbox (GaTech)\vaporwave\256x256png\A E S T H E T I C R E A L M - (AaronStraine)-08.png
# D:\Dropbox (GaTech)\vaporwave\256x256png\A E S T H E T I C R E A L M - (AaronStraine)-09.png
# D:\Dropbox (GaTech)\vaporwave\256x256png\A E S T H E T I C R E A L M - (AaronStraine)-10.png
# D:\Dropbox (GaTech)\vaporwave\256x256png\A E S T H E T I C R E A L M - (AaronStraine)-11.png
# D:\Dropbox (GaTech)\vaporwave\256x256png\A E S T H E T I C R E A L M - (AaronStraine)-12.png
# D:\Dropbox (GaTech)\vaporwave\256x256png\A E S T H E T I C R E A L M - (AaronStraine)-13.png
# D:\Dropbox (GaTech)\vaporwave\256x256png\A E S T H E T I C R E A L M - (AaronStraine)-14.png
# D:\Dropbox (GaTech)\vaporwave\256x256png\A E S T H E T I C R E A L M - (AaronStraine)-15.png
# D:\Dropbox (GaTech)\vaporwave\256x256png\A E S T H E T I C R E A L M - (AaronStraine)-16.png
# D:\Dropbox (GaTech)\vaporwave\256x256png\A E S T H E T I C R E A L M - (AaronStraine)-17.png
# D:\Dropbox (GaTech)\vaporwave\256x256png\A E S T H E T I C R E A L M - (AaronStraine)-18.png
# D:\Dropbox (GaTech)\vaporwave\256x256png\A E S T H E T I C R E A L M - (AaronStraine)-19.png
# D:\Dropbox (GaTech)\vaporwave\256x256png\A E S T H E T I C R E A L M - (AaronStraine)-20.png
# D:\Dropbox (GaTech)\vaporwave\256x256png\A E S T H E T I C R E A L M - (AaronStraine)-21.png
# ...
# D:\Dropbox (GaTech)\vaporwave\256x256png\Ｔｏｕｃｈ™ - (PSNSpankHenk).png
# D:\Dropbox (GaTech)\vaporwave\256x256png\ｔｏｕｇｈ ｌｏｖｅ 深爱 - (normalouise).png
# D:\Dropbox (GaTech)\vaporwave\256x256png\ＴＯＹ ＳＴＯＲＹ - (Deleted).png
# D:\Dropbox (GaTech)\vaporwave\256x256png\Ｔｒａｉｎ Ｒｉｄｅ - (JamesMacolini).png
# D:\Dropbox (GaTech)\vaporwave\256x256png\ＴＲＡＮＳＣＥＮＤＥＮＴ - (FuegoLord).png
# D:\Dropbox (GaTech)\vaporwave\256x256png\ＴＲＡＮＳＦＯＲＭ - (supyrb).png
# D:\Dropbox (GaTech)\vaporwave\256x256png\Ｔｒａｎｓｉｔｉｏｎｓ - (miimii1205).png
# D:\Dropbox (GaTech)\vaporwave\256x256png\Ｔｒａｎｓｌａｔｉｏｎ░／░Ｄｉｓｔｏｒｔｉｏｎ （ゼ飲塩） - (robness).png
# D:\Dropbox (GaTech)\vaporwave\256x256png\Ｔｒａｐｐｅｄ - (lukeetxe).png
# D:\Dropbox (GaTech)\vaporwave\256x256png\Ｔｒａｐｐｉｎ ｉｎ Ｔ Ｅ Ｘ Ａ Ｓ - (Redsnork).png
# D:\Dropbox (GaTech)\vaporwave\256x256png\ＴＲＡＳＨ ＰＩＣＫＵＰ - (BasicallySebastian).png
# D:\Dropbox (GaTech)\vaporwave\256x256png\ＴＲＩＡＮＧＬＥ ＬＯＶＥ - (supyrb).png
# D:\Dropbox (GaTech)\vaporwave\256x256png\Ｔｒｉｐｐｉｎ＇ Ｏｎ Ｔｈｅ Ｓｈｏｒｅ - (richhomiegeo).png
# D:\Dropbox (GaTech)\vaporwave\256x256png\Ｔｒｏｐｉｃａｌ Ｄｙｓｔｏｐｉａ - (Seph-Raz).png
# D:\Dropbox (GaTech)\vaporwave\256x256png\Ｔｒｏｐｉｃａｌ Ｌｕｘｕｒｙ - (PSNSpankHenk).png
# D:\Dropbox (GaTech)\vaporwave\256x256png\ｔｒｕｍｐ ｓｋｕｌｌ － ヨン石によって／シンプソン波 － ｓｉｍｐｓｏｎｗａｖｅ - (WeAreMachines).png
# D:\Dropbox (GaTech)\vaporwave\256x256png\Ｔｒｙｉｎｇ ｔｏ ａｐｐｒｏｘｉｍａｔｅ Ｖａｐｏｒｗａｖｅ ａｒｔ ｕｓｉｎｇ ｏｎｌｙ ｂｌａｃｋ ａｎｄ ｗｈｉｔｅ！ - (Deleted) - 2.png
# D:\Dropbox (GaTech)\vaporwave\256x256png\ＴＵＲＮ ＡＲＯＵＮＤ - (supyrb).png
# D:\Dropbox (GaTech)\vaporwave\256x256png\Ｔｕｘ－Ｓａｔａｎｉｓｔ Ｔｕｍｂｌｒ Ｇｉｒｌ - (DanTR).png
# D:\Dropbox (GaTech)\vaporwave\256x256png\Ｔｗｉｎｋ Ｌｕｋｅ Ｓｋｙｗａｌｋｅｒ ｉｓ ｔｈｅ Ｂｅｓｔ - (bobmarleykush420).png
# D:\Dropbox (GaTech)\vaporwave\256x256png\ＴＷＩＮＰＥＡＫＳ __ First attempt at this style of art - (Cairo-TenThirteen).png
# D:\Dropbox (GaTech)\vaporwave\256x256png\ｔｙｐｈｏｏｎ - (yellowt3a).png
# D:\Dropbox (GaTech)\vaporwave\256x256png\ｕ ｈ ｏ ｈ - (iodotsys).png
# D:\Dropbox (GaTech)\vaporwave\256x256png\Ｕ Ｒ Ａ Ｎ Ｕ Ｓ - (Seph-Raz).png
# D:\Dropbox (GaTech)\vaporwave\256x256png\ｕｂｅｒｍｅｎｓｃｈ - (_cicada3301).png
# D:\Dropbox (GaTech)\vaporwave\256x256png\ｕｍｂｒｅｌｌｏ - (SilveriteBlade).png
# D:\Dropbox (GaTech)\vaporwave\256x256png\ｕｎａｂｌｅ － ｔｏ － ｌｅｔ － ｇｏ - (evawsonsimp).png
# D:\Dropbox (GaTech)\vaporwave\256x256png\ｕｎｓｅｅｎ ｄａｒｋｎｅｓｓ - (loudgypsy).png
# D:\Dropbox (GaTech)\vaporwave\256x256png\ＵＮＳＰＯＫＥＮ ＦＡＮＴＡＳＩＥＳ - (rady123lol)-1.png
# D:\Dropbox (GaTech)\vaporwave\256x256png\ＵＮＳＰＯＫＥＮ ＦＡＮＴＡＳＩＥＳ - (rady123lol)-2.png
# D:\Dropbox (GaTech)\vaporwave\256x256png\ＵＮＳＰＯＫＥＮ ＦＡＮＴＡＳＩＥＳ - (rady123lol)-3.png
# D:\Dropbox (GaTech)\vaporwave\256x256png\ＵＮＴＩＴＬＥＤ _ _ Welcome to the new world - (FuegoLord).png
# D:\Dropbox (GaTech)\vaporwave\256x256png\ＵＮＴＩＴＬＥＤ__ Made by me some months ago - (FuegoLord).png
# D:\Dropbox (GaTech)\vaporwave\256x256png\ｕｎｔｉｔｌｅｄ１９８４ - (spur_22).png
# D:\Dropbox (GaTech)\vaporwave\256x256png\ＵＰ ＩＮ ＴＨＥ ＣＬＯＵＤＳ - (supyrb).png
# D:\Dropbox (GaTech)\vaporwave\256x256png\ｕｐｄａｔｅｄ - (yourselfiegotleaked).png
# D:\Dropbox (GaTech)\vaporwave\256x256png\ＵＰＴＯＷＮ 私を殺して - (claydayparade).png
# D:\Dropbox (GaTech)\vaporwave\256x256png\Ｕｒａｒａｋａ （Ｍｙ Ｈｅｒｏ Ａｃａｄｅｍｉａ） - (WavesofJapan).png
# D:\Dropbox (GaTech)\vaporwave\256x256png\Ｖ ａ ｐ ｏ ｒ ｉ ｓ ｌ ｉ ｆ １ ｆ ａ ｒ ｔ ｆ ｅ - (Heygamer).png
# D:\Dropbox (GaTech)\vaporwave\256x256png\ｖ ａ ｐ ｏ ｒ ｗ ａ ｖ ｅ ＼＼＼＼＼＼＼ ＦＲＡＣＴＡＬＳ - (FayeBlooded).png
# D:\Dropbox (GaTech)\vaporwave\256x256png\Ｖ Ｉ Ｎ Ｔ Ａ Ｇ Ｅ - (FatalTraction).png
# D:\Dropbox (GaTech)\vaporwave\256x256png\Ｖ ｕ ｌ ｃ ａ ｎ Ｂ ｌ ａ ｚ ｅ - (Seph-Raz).png
# D:\Dropbox (GaTech)\vaporwave\256x256png\ＶΛＰＯＲ ＷΛＶΞＳ - (ezrah01).png
# D:\Dropbox (GaTech)\vaporwave\256x256png\ＶＡＣＵＵＭ ＷＡＶＥ - (MagVapors).png
# D:\Dropbox (GaTech)\vaporwave\256x256png\ＶＡＬＥＮＴＩＮＥＳ - (wightknight121).png
# D:\Dropbox (GaTech)\vaporwave\256x256png\ｖａｎｉｌｌａ ｄｒｅａｍｓ '94 - (PSNSpankHenk).png
# D:\Dropbox (GaTech)\vaporwave\256x256png\ＶＡＰＥＴＯＷＥＲ - (wightknight121).png
# D:\Dropbox (GaTech)\vaporwave\256x256png\ＶＡＰＯＲ ＣＡＰＥ - (supyrb).png
# D:\Dropbox (GaTech)\vaporwave\256x256png\ｖａｐｏｒ ｄｅａｄ 死霊のはらわた - (PaperGoku).png
# D:\Dropbox (GaTech)\vaporwave\256x256png\Ｖａｐｏｒ Ｋｉｒｂｙ - (egzeltics).png
# D:\Dropbox (GaTech)\vaporwave\256x256png\ＶＡＰＯＲ ＯＳ Ｘ - (supyrb).png
# D:\Dropbox (GaTech)\vaporwave\256x256png\ＶＡＰＯＲ ＴＶ - (supyrb).png
# D:\Dropbox (GaTech)\vaporwave\256x256png\ｖａｐｏｒ__ｗａｖｅ - (PSNSpankHenk).png
# D:\Dropbox (GaTech)\vaporwave\256x256png\ｖａｐｏｒｄｅａｔｈ．ｊｐｅｇ - (jrdsctt).png
# D:\Dropbox (GaTech)\vaporwave\256x256png\ＶａｐｏｒＤｉｓｃ - (PSNSpankHenk).png
# D:\Dropbox (GaTech)\vaporwave\256x256png\ＶＡＰＯＲＥＧＯＮ [OC] - (CaptainBroverdose).png
# D:\Dropbox (GaTech)\vaporwave\256x256png\ＶＡＰＯＲＧＵＭ - (supyrb).png
# D:\Dropbox (GaTech)\vaporwave\256x256png\ｖａｐｏｒｉｚｅｒ － ＡＧＭ３－９０００ ｔｅｃｈ ゛ポ嵐ェ - (KennedyCreations).png
# D:\Dropbox (GaTech)\vaporwave\256x256png\Ｖａｐｏｒｍｉａｍｉ - (SpiderJuice7).png
# D:\Dropbox (GaTech)\vaporwave\256x256png\ＶａｐｏｒＳｏｆｔ™ - (PSNSpankHenk).png
# D:\Dropbox (GaTech)\vaporwave\256x256png\ＶＡＰＯＲＴＡＰＥ - (Prohamen).png
# D:\Dropbox (GaTech)\vaporwave\256x256png\ｖａｐｏｒｗａｖｅ &gt; Rock - (LimeTime_15).png
# D:\Dropbox (GaTech)\vaporwave\256x256png\ｖａｐｏｒｗａｖｅ ６４ - (JoeyMacaroni982_v2).png
# D:\Dropbox (GaTech)\vaporwave\256x256png\Ｖａｐｏｒｗａｖｅ ｉｓ ｔｈｅ ＮＥＷ ｄｒｕｇ, made by me - (Capt-Hereditarias).png
# D:\Dropbox (GaTech)\vaporwave\256x256png\Ｖａｐｏｒｗａｖｅ Ｍｏｄｅｌｏ ２０１７ - (FlatLine94).png
# D:\Dropbox (GaTech)\vaporwave\256x256png\Ｖａｐｏｒｗａｖｅ ｔｏｄｄｌｅｒ ｈｅｒｅ - (FoShizzleMaDrizzle).png
# D:\Dropbox (GaTech)\vaporwave\256x256png\Ｖａｐｏｒｗａｖｅ ｗａｌｌ ｐａｐｅｒ {ｆｒｅｅ} - (d3adb0i).png
# D:\Dropbox (GaTech)\vaporwave\256x256png\Ｖｅｅｓｉｏｎ - (Droploris).png
# D:\Dropbox (GaTech)\vaporwave\256x256png\ｖｅｎｉｃｅ - (samib909).png
# D:\Dropbox (GaTech)\vaporwave\256x256png\Ｖｅｒｓａｃｅ Ｖａｐｏｒｗａｖｅ - (paradoxpyrex).png
# D:\Dropbox (GaTech)\vaporwave\256x256png\ｖｅｒｙ - (ThrowawayPandaman).png
# D:\Dropbox (GaTech)\vaporwave\256x256png\ＶＨＳ 夢が叶います - (Crabon-6).png
# D:\Dropbox (GaTech)\vaporwave\256x256png\ＶＨＳ ＡＥＳＴＨＥＴＩＣＳ - (rumboogy).png
# D:\Dropbox (GaTech)\vaporwave\256x256png\ＶＨＳ ＰＡＲＡＤＩＳＥ - (supyrb).png
# D:\Dropbox (GaTech)\vaporwave\256x256png\ＶＩＣＥＷＡＶＥ - Vaporwave on Vice City - (Deleted).png
# D:\Dropbox (GaTech)\vaporwave\256x256png\ＶＩＤＥＯ ＣＡＳＳＥＴＴＥ １２０ 欧維偉 - (IanCharlesOfficial).png
# D:\Dropbox (GaTech)\vaporwave\256x256png\ｖｉｏｌｅｎｃｅ - (unlucki13).png
# D:\Dropbox (GaTech)\vaporwave\256x256png\ＶＩＲＴＵＡＬ - (fistofthebrownstar).png
# D:\Dropbox (GaTech)\vaporwave\256x256png\Ｖｉｒｔｕａｌ Ｃｏｎｔｅｍｐｌａｔｉｏｎ - (jspike91).png
# D:\Dropbox (GaTech)\vaporwave\256x256png\ｖｉｒｔｕａｌ ｌｉｆｅ - (Bristlethorn)-1.png
# D:\Dropbox (GaTech)\vaporwave\256x256png\ｖｉｒｔｕａｌ ｌｉｆｅ - (Bristlethorn)-2.png
# D:\Dropbox (GaTech)\vaporwave\256x256png\ｖｉｒｔｕａｌ ｌｉｆｅ - (Bristlethorn)-3.png
# D:\Dropbox (GaTech)\vaporwave\256x256png\ｖｉｒｔｕａｌ ｌｏｎｅｌｉｎｅｓｓ 仮想空虚 - (DisarmedFire).png
# D:\Dropbox (GaTech)\vaporwave\256x256png\ｖｉｒｔｕａｌ ｒｅｓｏｒｔ - (Dr_Paradox54).png
# D:\Dropbox (GaTech)\vaporwave\256x256png\ｖｉｒｔｕａｌ ｓｈａｐｅｓ - (MisdrawnChocolateBar).png
# D:\Dropbox (GaTech)\vaporwave\256x256png\Ｖｉｓｕａｌ Ｍｅｍｏｒｙ - (ctrl_mod-l).png
# D:\Dropbox (GaTech)\vaporwave\256x256png\Ｖｏｖａ - (OSnapItzTori).png
# D:\Dropbox (GaTech)\vaporwave\256x256png\Ｗ Λ Ｖ Ξ Ｓ - (Punchkinz).png
# D:\Dropbox (GaTech)\vaporwave\256x256png\ｗ ａ ｋ ｅ ｕ ｐ - (Deleted).png
# D:\Dropbox (GaTech)\vaporwave\256x256png\Ｗ ｈ ａ ｔ － ｉ － Ａ ｍ ッゞ・お炎ミ ー汚キ - (evawsonsimp).png
# D:\Dropbox (GaTech)\vaporwave\256x256png\ｗ ｉ ｎ ｄ ｏ ｗ ｓ - (Jaskarn565).png
# D:\Dropbox (GaTech)\vaporwave\256x256png\ＷΛＳＨΞＤΛＷΛＹ 3 . 1（穏謁ゔ） - (skyfucker6).png
# D:\Dropbox (GaTech)\vaporwave\256x256png\Ｗ９５ ｅｒａｓｅ ｍｅ - (rady123lol).png
# D:\Dropbox (GaTech)\vaporwave\256x256png\ＷＡＩＴＩＮＧ ＦＯＲ ＹＯＵ - (supyrb).png
# D:\Dropbox (GaTech)\vaporwave\256x256png\Ｗａｉｔｉｎｇ Ｏｎ Ｍｙ Ａｎｇｅｌ.mp3 - (ctrl_mod-l).png
# D:\Dropbox (GaTech)\vaporwave\256x256png\ｗａｋｅ ｕｐ - (dgtlartbyfriedrich).png
# D:\Dropbox (GaTech)\vaporwave\256x256png\ｗａｌｌｐａｐｅｒ - (jasc5797).png
# D:\Dropbox (GaTech)\vaporwave\256x256png\ｗａｌｌｐａｐｅｒ ね悦彙 - (batikus).png
# D:\Dropbox (GaTech)\vaporwave\256x256png\Ｗａｎｔｅｄ ｔｏ ｒｅｃｒｅａｔｅ ｍｙ ｔｒｉｐ ｏｎ ＬＳＤ． - (rady123lol)-1.png
# D:\Dropbox (GaTech)\vaporwave\256x256png\Ｗａｎｔｅｄ ｔｏ ｒｅｃｒｅａｔｅ ｍｙ ｔｒｉｐ ｏｎ ＬＳＤ． - (rady123lol)-2.png
# D:\Dropbox (GaTech)\vaporwave\256x256png\ＷＡＳ ＩＴ ＷＯＲＴＨ ＩＴ ＩＮ ＴＨＥ ＥＮＤ？ - (Kaihatsu).png
# D:\Dropbox (GaTech)\vaporwave\256x256png\ｗａｔｃｈｉｎｇ ｔｈｅ ｓｕｎｓｅｔ ｗｉｔｈ ｂａｅ - (lukeetxe).png
# D:\Dropbox (GaTech)\vaporwave\256x256png\Ｗａｔｅｒｆａｌｌ 円益鉛 - (Vzation).png
# D:\Dropbox (GaTech)\vaporwave\256x256png\ｗａｖｅ ｃｉｔｙ - (Bristlethorn)-1.png
# D:\Dropbox (GaTech)\vaporwave\256x256png\ｗａｖｅ ｃｉｔｙ - (Bristlethorn)-2.png
# D:\Dropbox (GaTech)\vaporwave\256x256png\ｗａｖｅ ｃｉｔｙ - (Bristlethorn)-3.png
# D:\Dropbox (GaTech)\vaporwave\256x256png\ｗａｖｅ ｃｉｔｙ - (Bristlethorn)-4.png
# D:\Dropbox (GaTech)\vaporwave\256x256png\ｗａｖｅ／／ＭＩＳＴ - (mazz1224).png
# D:\Dropbox (GaTech)\vaporwave\256x256png\ＷＡＶＥＳ - (Preyker).png
# D:\Dropbox (GaTech)\vaporwave\256x256png\ＷＡＶＥＳ ＰＡＲＴ ＴＷＯ - (moby3).png
# D:\Dropbox (GaTech)\vaporwave\256x256png\ＷＡＶＹ - (Deleted) - 2.png
# D:\Dropbox (GaTech)\vaporwave\256x256png\ＷＡＶＹ - (Deleted) - 3.png
# D:\Dropbox (GaTech)\vaporwave\256x256png\ＷＡＶＹ - (Deleted).png
# D:\Dropbox (GaTech)\vaporwave\256x256png\ＷＡＶＹ - (supyrb).png
# D:\Dropbox (GaTech)\vaporwave\256x256png\ＷＡＶＹ ＶＡＰＯＲ ＦＬＯＷ - (supyrb).png
# D:\Dropbox (GaTech)\vaporwave\256x256png\ｗｅ ａｒｅ ｃｏｇｓ - (Dr_Paradox54).png
# D:\Dropbox (GaTech)\vaporwave\256x256png\Ｗｅ ａｒｅ Ｆｒｅｅ ｅｘｅ - (H20DDs).png
# D:\Dropbox (GaTech)\vaporwave\256x256png\ＷＥ ＡＲＥ ＴＨＥ ＤＥＡＤ ＧＥＮＥＲＡＴＩＯＮ - (alastorthompson).png
# D:\Dropbox (GaTech)\vaporwave\256x256png\ＷＥ ＨＡＶＥ ＫＩＬＬＥＤ ＩＴ - (CoolUsernameIsItNot).png
# D:\Dropbox (GaTech)\vaporwave\256x256png\ｗｅ ｌｉｖｅ ａ ｌｉｅ. [OC] - (WizKrablifa).png
# D:\Dropbox (GaTech)\vaporwave\256x256png\Ｗｅ░ａｒｅ░ａｌｌ░ｂｅａｕｔｉｆｕｌ - (PedroHB).png
# D:\Dropbox (GaTech)\vaporwave\256x256png\ＷＥ＇ＲＥ ＡＬＬ ＢＲＯＫＥＮ - (Trxpdoor).png
# D:\Dropbox (GaTech)\vaporwave\256x256png\ＷＥＬＣＯＭＥ - (supyrb).png
# D:\Dropbox (GaTech)\vaporwave\256x256png\ＷＥＬＣＯＭＥ ＨＯＭＥ - (supyrb).png
# D:\Dropbox (GaTech)\vaporwave\256x256png\Ｗｅｌｃｏｍｅ ｈｏｍｅ， ｄｅａｒ！ - (DeletedMessiah).png
# D:\Dropbox (GaTech)\vaporwave\256x256png\ＷＥＬＣＯＭＥ ＴＯ ＭＩＡＭＩ - (12ayylmao132).png
# D:\Dropbox (GaTech)\vaporwave\256x256png\ｗｅｌｃｏｍｅ ｔｏ ｔｈｅ １９９１ ｃａｐｉｔａｌ ｏｆ ｃａｐｉｔａｌｉｓｍ - (TheLittleLebowsk).png
# D:\Dropbox (GaTech)\vaporwave\256x256png\Ｗｅｌｃｏｍｅ ｔｏ ｔｈｅ Ｖｉｒｔｕａｌ Ｗｏｒｌｄ （ＯＣ） - (Jeimuzu_MC).png
# D:\Dropbox (GaTech)\vaporwave\256x256png\ＷＥＬＣＯＭＥ, Ｄａｉｓｙ[OC] - (DanTR).png
# D:\Dropbox (GaTech)\vaporwave\256x256png\Ｗｅｔ░Ｐｈｏｎｅ░Ｓｉｔｕａｔｉｏｎ （唄安ゖ） - (robness).png
# D:\Dropbox (GaTech)\vaporwave\256x256png\Ｗｈａｔ ａ ｄｉｆｆｅｒｅｎｃｅ - (refused73).png
# D:\Dropbox (GaTech)\vaporwave\256x256png\ｗｈａｔ ａｒｅ ｙｏｕ？ follow me_ @kairukundesu - (SuicidalButNotReally).png
# D:\Dropbox (GaTech)\vaporwave\256x256png\ｗｈａｔ ｄｏ ｙｏｕ ｄｏ？ - (RallyFTW).png
# D:\Dropbox (GaTech)\vaporwave\256x256png\Ｗｈａｔ Ｉ ｓｅｅ 私が見るもの.jpg - (PsdeudoN764).png
# D:\Dropbox (GaTech)\vaporwave\256x256png\ｗｈａｔ ｉｓ ｌｉｆｅ ｂｕｔ ａ ｍｅａｎｓ ｏｆ ｄｅｓｔｒｕｃｔｉｏｎ？ - (TheCoolman78).png
# D:\Dropbox (GaTech)\vaporwave\256x256png\Ｗｈａｔ ｗｏｕｌｄ ｙｏｕ ｄｏ ｉｆ ｙｏｕ ｋｎｅｗ ｙｏｕ ｏｎｌｙ ｈａｄ ｔｈｒｅｅ ｄａｙｓ ｔｏ ｌｉｖｅ？ - (Jrwer).png
# D:\Dropbox (GaTech)\vaporwave\256x256png\ｗｈａｔ ｗｏｕｌｄ ｙｏｕ ｌｉｋｅ ｔｏ ｅａｔ ｔｏｄａｙ？ - (HonoluluBlueMusic).png
# D:\Dropbox (GaTech)\vaporwave\256x256png\Ｗｈｅｅｌｓ (ホイール) - (VaporwaveRide).png
# D:\Dropbox (GaTech)\vaporwave\256x256png\ｗｈｅｎ？ ｗｈｅｒｅ？ ｗｈｙ？ - (fons_garmo).png
# D:\Dropbox (GaTech)\vaporwave\256x256png\ｗｈｅｒｅ ａｍ ｉ ｗｈｏ ｃａｒｅｓ - (kurodon85).png
# D:\Dropbox (GaTech)\vaporwave\256x256png\ｗｈｅｒｅ ａｍ ｉ？ - (darkman9333).png
# D:\Dropbox (GaTech)\vaporwave\256x256png\Ｗｈｅｒｅ ｄｏ ｙｏｕ ｗａｎｔ ｔｏ ｇｏ ｔｏｄａｙ？ ぇ ヺ映嵐ューー - (Limit_IV).png
# D:\Dropbox (GaTech)\vaporwave\256x256png\ＷＨＥＲＥ ＩＳ ＭＹ ＢＬＵＥＳＣＲＥＥＮ？ - (supyrb).png
# D:\Dropbox (GaTech)\vaporwave\256x256png\ＷＨＥＲＥ ＩＳ ＭＹ ＦＡＣＥ？ - (supyrb).png
# D:\Dropbox (GaTech)\vaporwave\256x256png\Ｗｈｅｒｅ ｉｓ ｔｈｅ Ｌｏｖｅ？ - (DoubleBlackHeart).png
# D:\Dropbox (GaTech)\vaporwave\256x256png\ｗｈｅｒｅ ｙｏｕ ｂｅｌｏｎｇ [OC] - (Diagbro).png
# D:\Dropbox (GaTech)\vaporwave\256x256png\ｗｈｏ ａｒｅ ｙｏｕ - (sai501).png
# D:\Dropbox (GaTech)\vaporwave\256x256png\ｗｈｏ ａｒｅ ｙｏｕ？ - (not___an__artist_).png
# D:\Dropbox (GaTech)\vaporwave\256x256png\ｗｈｏ ｉｓ ｓｈｅ．．．？ - (Gobitto).png
# D:\Dropbox (GaTech)\vaporwave\256x256png\ｗｈｏ ｉｓ ｔｈｅ _ｄｒｅａｍｅｒ_ - (vape_tent).png
# D:\Dropbox (GaTech)\vaporwave\256x256png\Ｗｈｏｓ Ｔｈｅ Ｂｏｓｓ？ - (refused73).png
# D:\Dropbox (GaTech)\vaporwave\256x256png\ｗｉｄｅｓｃａｐｅ - (ReigsManx).png
# D:\Dropbox (GaTech)\vaporwave\256x256png\ＷＩＬＬ ＳＨＥ ＥＶＥＲ ＣＯＭＥ ＢＡＣＫ？ - (Invisible-Gear).png
# D:\Dropbox (GaTech)\vaporwave\256x256png\Ｗｉｌｌｙ Ｗｏｎｋａ - (johnfedoras).png
# D:\Dropbox (GaTech)\vaporwave\256x256png\ｗｉｎｄｏｗｓ - (YanSinJurai).png
# D:\Dropbox (GaTech)\vaporwave\256x256png\Ｗｉｎｄｏｗｓ ９５ - (Jlnhlfan).png
# D:\Dropbox (GaTech)\vaporwave\256x256png\Ｗｉｎｄｏｗｓ ＧａｍｅＢｏｙ ９５ - (jspike91).png
# D:\Dropbox (GaTech)\vaporwave\256x256png\ｗｉｎｄｏｗｓ-ｓｅａ.ｐｓｄ - (Deleted).png
# D:\Dropbox (GaTech)\vaporwave\256x256png\Ｗｉｎｄｏｗｓｈｏｐｐｉｎｇ - (ReizX).png
# D:\Dropbox (GaTech)\vaporwave\256x256png\ｗｉｎｄｏｗｓｈｏｐｐｉｎｇ - (wk2012).png
# D:\Dropbox (GaTech)\vaporwave\256x256png\ｗｉｎｄｙ - (arrowhead_project).png
# D:\Dropbox (GaTech)\vaporwave\256x256png\Ｗｉｎｇｅｄ Ｖｉｃｔｏｒｙ (勝利) - (konahriik21).png
# D:\Dropbox (GaTech)\vaporwave\256x256png\Ｗｉｔｈ Ｂａｅ - (rady123lol).png
# D:\Dropbox (GaTech)\vaporwave\256x256png\Ｗｉｔｈ ｂｏｔｈ ｄｉｒｅｃｔｉｏｎ， ａｎｄ ｍａｇｎｉｔｕｄｅ - (LlamaThrust666).png
# D:\Dropbox (GaTech)\vaporwave\256x256png\Ｗｉｔｈ ｃｏｍｒａｄｅｓ ｉｎ ｐｌａｚａ - (rady123lol).png
# D:\Dropbox (GaTech)\vaporwave\256x256png\ｗｉｔｈ ｙｏｕｒ ｔｈｏｕｇｈｔｓ， ｙｏｕ ｍａｋｅ ｔｈｅ ｗｏｒｌｄ - (CosTrader).png
# D:\Dropbox (GaTech)\vaporwave\256x256png\Ｗｏｋｅ ｕｐ ｉｎ ａ Ｄｒｅａｍ - Vaporwave-esque Music &amp; Visualizer - (EarthlingInMotion).png
# D:\Dropbox (GaTech)\vaporwave\256x256png\ｗｏｍａｎ - (vaporcolorsdotcom).png
# D:\Dropbox (GaTech)\vaporwave\256x256png\ｗｏｍａｎ - (vaporcolorsdotcom).png.png
# D:\Dropbox (GaTech)\vaporwave\256x256png\ｗｏｒｄｓ／ ａｅｓｔｈｅｔｉｃｓ - (ThrowawayPandaman).png
# D:\Dropbox (GaTech)\vaporwave\256x256png\ｗｏｒｌｄ ｏｆ ｓａｎｄ - (CitizenPremier).png
# D:\Dropbox (GaTech)\vaporwave\256x256png\ｙ ｅ ｓ - (Jaskarn565).png
# D:\Dropbox (GaTech)\vaporwave\256x256png\ＹＡＢ - (12ayylmao132).png
# D:\Dropbox (GaTech)\vaporwave\256x256png\ｙｏｇｈｕｒｔ - (Murmaider96).png
# D:\Dropbox (GaTech)\vaporwave\256x256png\Ｙｏｕ ａｒｅ ａ ｎｏｄｅ ｏｎ ｔｈｅ ｎｅｔｗｏｒｋ - (garrisonxci).png
# D:\Dropbox (GaTech)\vaporwave\256x256png\ＹＯＵ ＡＲＥ ＡＧＩＮＧ - (Poockiy).png
# D:\Dropbox (GaTech)\vaporwave\256x256png\ＹＯＵ ＡＲＥ ＭＹ ＲＥＡＳＯＮ ＴＯ ＦＩＧＨＴ - (ChamanOfTheIsla).png
# D:\Dropbox (GaTech)\vaporwave\256x256png\ｙｏｕ ｃａｎ＇ｔ ｈｉｄｅ ｉｎ ａ ｐｕｒｓｅ - (evaunitone).png
# D:\Dropbox (GaTech)\vaporwave\256x256png\Ｙｏｕ ｃａｎｎｏｔ＇ｔ ｄｏ ｔｈａｔ - (miimii1205).png
# D:\Dropbox (GaTech)\vaporwave\256x256png\ｙｏｕ ｋｎｏｗ ｗｈｙ - (louann1812).png
# D:\Dropbox (GaTech)\vaporwave\256x256png\ｙｏｕ ｗｉｌｌ ｂｅ ａｌｏｎｅ - (zdrwal).png
# D:\Dropbox (GaTech)\vaporwave\256x256png\ｙｏｕ＇ｒｅ ｇｏｉｎｇ ｎｏｗｈｅｒｅ - (adventure_hat).png
# D:\Dropbox (GaTech)\vaporwave\256x256png\Ｙｏｕ＇ｒｅ ｗｏｒｔｈ ｉｔ - (TBronsonIves).png
# D:\Dropbox (GaTech)\vaporwave\256x256png\ｙｏｕ＇ｒｅ⠀ａｌｗａｙｓ⠀ｏｎ⠀ｍｙ⠀ｍｉｎｄ ｜ いつも⠀［ＯＣ］ - (atmosphyx).png
# D:\Dropbox (GaTech)\vaporwave\256x256png\ｙｏｕｒ ｂｅｓｔ ｆｒｉｅｎｄ - (adventure_hat).png
# D:\Dropbox (GaTech)\vaporwave\256x256png\Ｙｏｕｒ ｌｉｆｅ ｉｓ ａ ＥＲＲＯＲ - (VHS-CAT).png
# D:\Dropbox (GaTech)\vaporwave\256x256png\ｙｏｕｒｅ ｗｉｎｎｅｒあわや - (migretros).png
# D:\Dropbox (GaTech)\vaporwave\256x256png\ＹＵＮＧ ＭＡＲＸ ．ＧＩＦ - (bperki8).png
# D:\Dropbox (GaTech)\vaporwave\256x256png\ｚｅｌｄａｂｏｙ６４ - (CuriousChristianity).png
# D:\Dropbox (GaTech)\vaporwave\256x256png\ＺＥＮ ＧＡＲＤＥＮ (procedurally generated) - (miimii1205).png
# D:\Dropbox (GaTech)\vaporwave\256x256png\Ｚｅｒｏ ｃａｌｏｒｉｅｓ - (mariuster).png
# D:\Dropbox (GaTech)\vaporwave\256x256png\ｚｉｎｅ ｓａｍｐｌｅ ｌ̴̡͓̲̖̯̲̃͜ｅ̶̡̨̫̼̩̝̫͔̺̘̮͕̏̑̂́͛͂̅́̑ͅ - (IanCharlesOfficial).png
# D:\Dropbox (GaTech)\vaporwave\256x256png\ｚｏｎｅｄ ｏｕｔ - (CosTrader).png
# D:\Dropbox (GaTech)\vaporwave\256x256png\Ｚｏｏｔｏｐｉａ－１９８４ - (EvilStevilTheKenevil).png
# D:\Dropbox (GaTech)\vaporwave\256x256png\ｚ￭ｅ￭ｌ￭ｄ￭ａ - (CuriousChristianity).png
# D:\Dropbox (GaTech)\vaporwave\256x256png\［ａｂｏｕｔ ｔｏ ｃｒｙ］ follow me_ @kairukundesu - (SuicidalButNotReally).png
# D:\Dropbox (GaTech)\vaporwave\256x256png\［Ｖｉｄｅｏ Ｊｕｎｔａ］ - (555WESIP).png
# D:\Dropbox (GaTech)\vaporwave\256x256png\＼／／＼ｐ０ｒ＼／＼／／＼＼／３＿１０ - (jrdsctt).png
# D:\Dropbox (GaTech)\vaporwave\256x256png\＿ｐｕｒｐｌｅＷａｖｅｓ [Just starting out, Feedback_ Good_ Bad_] - (_saltFantasy).png
# D:\Dropbox (GaTech)\vaporwave\256x256png\～ｇｏｏｄｂｙｅ ｍｏｏｎｍｅｎ® - (dankmattur).png
# D:\Dropbox (GaTech)\vaporwave\256x256png\～ｋｅｖｉｎｗａｖｅ～ edit - (heyitschet).png
# X_data shape: (17398, 256, 256, 3)

# %%
np.save('vaporwave', X_data)

# %%
loaded = np.load('vaporwave.npy')

# %%
loaded.shape
# Out:
# (17398, 256, 256, 3)

# %% [markdown]
# ## Progressive GAN

# %%
import numpy as np
from numpy import expand_dims
from numpy import zeros
from numpy import ones
from numpy import vstack
from numpy.random import randn
from numpy.random import randint
from keras.optimizers import Adam
from keras.models import Sequential, load_model
from keras.models import Model
from keras.layers import Input
from keras.layers import Dense
from keras.layers import Flatten
from keras.layers import Activation
from keras.layers import Reshape
from keras.layers import Conv2D
from keras.layers import UpSampling2D
from keras.layers import AveragePooling2D
from keras.layers import LeakyReLU
from keras.layers import BatchNormalization
from keras.layers import Add
from keras.utils.vis_utils import plot_model
from keras import backend
from skimage.transform import resize
import matplotlib.pyplot as pyplot
import sys
from typing import List, Tuple, Dict

# %%
def load_real_samples():
	# load Vaporarray dataset
	X = np.load('./vaporwave.npy')
	return X

# %%
load_real_samples().shape
# Out:
# (17398, 256, 256, 3)

# %%
# example of defining composite models for the progressive growing gan
# weighted sum output
class WeightedSum(Add):
	# init with default value
	def __init__(self, alpha=0.0, **kwargs):
		super(WeightedSum, self).__init__(**kwargs)
		self.alpha = backend.variable(alpha, name='ws_alpha')

	# output a weighted sum of inputs
	def _merge_function(self, inputs):
		# only supports a weighted sum of two inputs
		assert (len(inputs) == 2)
		# ((1-a) * input1) + (a * input2)
		output = ((1.0 - self.alpha) * inputs[0]) + (self.alpha * inputs[1])
		return output

def generate_real_samples(dataset, n_samples):
	# choose random instances
	ix = randint(0, dataset.shape[0], n_samples)
	# retrieve selected images
	X = dataset[ix]
	# generate 'real' class labels (1)
	y = np.random.uniform(low=0.8, high=1, size=(n_samples,1))
	return X, y

# generate points in latent space as input for the generator
def generate_latent_points(latent_dim: int, n_samples: int) -> np.array:
	# generate points in the latent space
	x_input = randn(latent_dim * n_samples)
	# reshape into a batch of inputs for the network
	x_input = x_input.reshape(n_samples, latent_dim)
	return x_input

# use the generator to generate n fake examples, with class labels
def generate_fake_samples(g_model, latent_dim: int, n_samples: int) -> Tuple[np.array, np.array]:
	# generate points in latent space
	x_input = generate_latent_points(latent_dim, n_samples)
	# predict outputs
	X = g_model.predict(x_input)
	# create 'fake' class labels (0)
	y = zeros((n_samples, 1))
	return X, y

# create and save a plot of generated images
def save_plot(examples: np.array, epoch: int, n=7):
	# plot images
	examples
	for i in range(n * n):
		# define subplot
		pyplot.subplot(n, n, 1 + i)
		# turn off axis
		pyplot.axis('off')
		# plot raw pixel data
		pyplot.imshow(examples[i])
	# save plot to file
	filename = 'vaporwave_e%03d.png' % (epoch+1)
	pyplot.savefig(filename)
	pyplot.close()
    
# evaluate the discriminator, plot generated images, save generator model
def summarize_performance(epoch: int, g_model, d_model, dataset, latent_dim, n_samples=150) -> None:
	# prepare fake examples
	x_fake, y_fake = generate_fake_samples(g_model, latent_dim, n_samples)
	# save plot
	save_plot(x_fake, epoch)
	# save the generator model tile file
	filename = 'generator_model_%03d.h5' % (epoch+1)
	g_model.save(filename)

# add a discriminator block
def add_discriminator_block(old_model, n_input_layers=3):
	# get shape of existing model
	in_shape = list(old_model.input.shape)
	# define new input shape as double the size
	input_shape = (in_shape[-2].value*2, in_shape[-2].value*2, in_shape[-1].value)
	in_image = Input(shape=input_shape)
	# define new input processing layer
	d = Conv2D(res // 2, (1,1), padding='same', kernel_initializer='he_normal')(in_image)
	d = LeakyReLU(alpha=0.2)(d)
	# define new block
	d = Conv2D(res // 2, (3,3), padding='same', kernel_initializer='he_normal')(d)
	d = BatchNormalization()(d)
	d = LeakyReLU(alpha=0.2)(d)
	d = Conv2D(res // 2, (3,3), padding='same', kernel_initializer='he_normal')(d)
	d = BatchNormalization()(d)
	d = LeakyReLU(alpha=0.2)(d)
	d = AveragePooling2D()(d)
	block_new = d
	# skip the input, 1x1 and activation for the old model
	for i in range(n_input_layers, len(old_model.layers)):
		d = old_model.layers[i](d)
	# define straight-through model
	model1 = Model(in_image, d)
	# compile model
	model1.compile(loss='mse', optimizer=Adam(lr=0.0004, beta_1=0, beta_2=0.99, epsilon=10e-8))
	# downsample the new larger image
	downsample = AveragePooling2D()(in_image)
	# connect old input processing to downsampled new input
	block_old = old_model.layers[1](downsample)
	block_old = old_model.layers[2](block_old)
	# fade in output of old model input layer with new input
	d = WeightedSum()([block_old, block_new])
	# skip the input, 1x1 and activation for the old model
	for i in range(n_input_layers, len(old_model.layers)):
		d = old_model.layers[i](d)
	# define straight-through model
	model2 = Model(in_image, d)
	# compile model
	model2.compile(loss='mse', optimizer=Adam(lr=0.0004, beta_1=0, beta_2=0.99, epsilon=10e-8))
	return [model1, model2]

# define the discriminator models for each image resolution
def define_discriminator(n_blocks: int, input_shape=(4,4,3)) -> list:
	model_list = list()
	# base model input
	in_image = Input(shape=input_shape)
	# conv 1x1
	d = Conv2D(res // 2, (1,1), padding='same', kernel_initializer='he_normal')(in_image)
	d = LeakyReLU(alpha=0.2)(d)
	# conv 3x3 (output block)
	d = Conv2D(res, (3,3), padding='same', kernel_initializer='he_normal')(d)
	d = BatchNormalization()(d)
	d = LeakyReLU(alpha=0.2)(d)
	# conv 4x4
	d = Conv2D(res, (4,4), padding='same', kernel_initializer='he_normal')(d)
	d = BatchNormalization()(d)
	d = LeakyReLU(alpha=0.2)(d)
	# dense output layer
	d = Flatten()(d)
	out_class = Dense(1)(d)
	# define model
	model = Model(in_image, out_class)
	# compile model
	model.compile(loss='mse', optimizer=Adam(lr=0.0004, beta_1=0, beta_2=0.99, epsilon=10e-8))
	# store model
	model_list.append([model, model])
	# create submodels
	for i in range(1, n_blocks):
		# get prior model without the fade-on
		old_model = model_list[i - 1][0]
		# create new model for next resolution
		models = add_discriminator_block(old_model)
		# store model
		model_list.append(models)
	return model_list

# add a generator block
def add_generator_block(old_model):
	# get the end of the last block
	block_end = old_model.layers[-2].output
	# upsample, and define new block
	upsampling = UpSampling2D()(block_end)
	g = Conv2D(res // 2, (3,3), padding='same', kernel_initializer='he_normal')(upsampling)
	g = BatchNormalization()(g)
	g = LeakyReLU(alpha=0.2)(g)
	g = Conv2D(res // 2, (3,3), padding='same', kernel_initializer='he_normal')(g)
	g = BatchNormalization()(g)
	g = LeakyReLU(alpha=0.2)(g)
	# add new output layer
	out_image = Conv2D(3, (1,1), padding='same', kernel_initializer='he_normal')(g)
	# define model
	model1 = Model(old_model.input, out_image)
	# get the output layer from old model
	out_old = old_model.layers[-1]
	# connect the upsampling to the old output layer
	out_image2 = out_old(upsampling)
	# define new output image as the weighted sum of the old and new models
	merged = WeightedSum()([out_image2, out_image])
	# define model
	model2 = Model(old_model.input, merged)
	return [model1, model2]

# define generator models
def define_generator(latent_dim: int, n_blocks: int, in_dim=4) -> list:
	model_list = list()
	# base model latent input
	in_latent = Input(shape=(latent_dim,))
	# linear scale up to activation maps
	g  = Dense(res * in_dim * in_dim, kernel_initializer='he_normal')(in_latent)
	g = Reshape((in_dim, in_dim, res))(g)
	# conv 4x4, input block
	g = Conv2D(res, (3,3), padding='same', kernel_initializer='he_normal')(g)
	g = BatchNormalization()(g)
	g = LeakyReLU(alpha=0.2)(g)
	# conv 3x3
	g = Conv2D(res, (3,3), padding='same', kernel_initializer='he_normal')(g)
	g = BatchNormalization()(g)
	g = LeakyReLU(alpha=0.2)(g)
	# conv 1x1, output block
	out_image = Conv2D(3, (1,1), padding='same', kernel_initializer='he_normal', activation = 'sigmoid')(g)
	# define model
	model = Model(in_latent, out_image)
	# store model
	model_list.append([model, model])
	# create submodels
	for i in range(1, n_blocks):
		# get prior model without the fade-on
		old_model = model_list[i - 1][0]
		# create new model for next resolution
		models = add_generator_block(old_model)
		# store model
		model_list.append(models)
	return model_list

# define composite models for training generators via discriminators
def define_composite(discriminators: list, generators: list) -> list:
	model_list = list()
	# create composite models
	for i in range(len(discriminators)):
		g_models, d_models = generators[i], discriminators[i]
		# straight-through model
		d_models[0].trainable = False
		model1 = Sequential()
		model1.add(g_models[0])
		model1.add(d_models[0])
		model1.compile(loss='mse', optimizer=Adam(lr=0.0001, beta_1=0, beta_2=0.99, epsilon=10e-8))
		# fade-in model
		d_models[1].trainable = False
		model2 = Sequential()
		model2.add(g_models[1])
		model2.add(d_models[1])
		model2.compile(loss='mse', optimizer=Adam(lr=0.0001, beta_1=0, beta_2=0.99, epsilon=10e-8))
		# store
		model_list.append([model1, model2])
	return model_list

# define models
discriminators = define_discriminator(n_blocks - 1)
# define models
generators = define_generator(100, n_blocks - 1)
# define composite models
composite = define_composite(discriminators, generators)
# Out:
# WARNING:tensorflow:From d:\github\vaporwave-gan\vaporprogan\venv\lib\site-packages\keras\backend\tensorflow_backend.py:66: The name tf.get_default_graph is deprecated. Please use tf.compat.v1.get_default_graph instead.
#
# WARNING:tensorflow:From d:\github\vaporwave-gan\vaporprogan\venv\lib\site-packages\keras\backend\tensorflow_backend.py:541: The name tf.placeholder is deprecated. Please use tf.compat.v1.placeholder instead.
#
# WARNING:tensorflow:From d:\github\vaporwave-gan\vaporprogan\venv\lib\site-packages\keras\backend\tensorflow_backend.py:4479: The name tf.truncated_normal is deprecated. Please use tf.random.truncated_normal instead.
#
# WARNING:tensorflow:From d:\github\vaporwave-gan\vaporprogan\venv\lib\site-packages\keras\backend\tensorflow_backend.py:190: The name tf.get_default_session is deprecated. Please use tf.compat.v1.get_default_session instead.
#
# WARNING:tensorflow:From d:\github\vaporwave-gan\vaporprogan\venv\lib\site-packages\keras\backend\tensorflow_backend.py:197: The name tf.ConfigProto is deprecated. Please use tf.compat.v1.ConfigProto instead.
#
# WARNING:tensorflow:From d:\github\vaporwave-gan\vaporprogan\venv\lib\site-packages\keras\backend\tensorflow_backend.py:2041: The name tf.nn.fused_batch_norm is deprecated. Please use tf.compat.v1.nn.fused_batch_norm instead.
#
# WARNING:tensorflow:From d:\github\vaporwave-gan\vaporprogan\venv\lib\site-packages\keras\optimizers.py:793: The name tf.train.Optimizer is deprecated. Please use tf.compat.v1.train.Optimizer instead.
#
# WARNING:tensorflow:From d:\github\vaporwave-gan\vaporprogan\venv\lib\site-packages\keras\backend\tensorflow_backend.py:4271: The name tf.nn.avg_pool is deprecated. Please use tf.nn.avg_pool2d instead.
#
# WARNING:tensorflow:From d:\github\vaporwave-gan\vaporprogan\venv\lib\site-packages\keras\backend\tensorflow_backend.py:2239: The name tf.image.resize_nearest_neighbor is deprecated. Please use tf.compat.v1.image.resize_nearest_neighbor instead.

# %% [markdown]
# **Fade-in/-out**
#
# This is a crucially part of building the model, where the different layers of the progression are merged into one training model.

# %%
# update the alpha value on each instance of WeightedSum
def update_fadein(models, step, n_steps):
	# calculate current alpha (linear from 0 to 1)
	alpha = step / float(n_steps - 1)
	# update the alpha for each model
	for model in models:
		for layer in model.layers:
			if isinstance(layer, WeightedSum):
				backend.set_value(layer.alpha, alpha)
                
# train a generator and discriminator
def train_epochs(g_model, d_model, gan_model, dataset, n_epochs, n_batch, fadein=False):
	# calculate the number of batches per training epoch
	bat_per_epo = dataset.shape[0] // n_batch
	# calculate the number of training iterations
	n_steps = bat_per_epo * n_epochs
	# calculate the size of half a batch of samples
	half_batch = n_batch // 2
	# manually enumerate epochs
	for i in range(n_steps):
		# update alpha for all WeightedSum layers when fading in new blocks
		if fadein:
			update_fadein([g_model, d_model, gan_model], i, n_steps)
		# prepare real and fake samples
		X_real, y_real = generate_real_samples(dataset, half_batch)
		X_fake, y_fake = generate_fake_samples(g_model, latent_dim, half_batch)
		# update discriminator model
		d_loss1 = d_model.train_on_batch(X_real, y_real)
		d_loss2 = d_model.train_on_batch(X_fake, y_fake)
		# update the generator via the discriminator's error
		z_input = generate_latent_points(latent_dim, n_batch)
		y_real2 = ones((n_batch, 1))
		g_loss = gan_model.train_on_batch(z_input, y_real2)
        
# scale images to preferred size
def scale_dataset(images, new_shape):
	images_list = list()
	for image in images:
		# resize with nearest neighbor interpolation
		new_image = resize(image, new_shape, 0)
		# store
		images_list.append(new_image)
	return np.asarray(images_list)

# train the generator and discriminator
def train(g_models, d_models, gan_models, dataset, latent_dim, e_norm, e_fadein, n_batch):
	# fit the baseline model
	g_normal, d_normal, gan_normal = g_models[0][0], d_models[0][0], gan_models[0][0]
	# scale dataset to appropriate size
	gen_shape = g_normal.output_shape
	scaled_data = scale_dataset(dataset, gen_shape[1:])
	print('Scaled Data', scaled_data.shape)
	# train normal or straight-through models
	train_epochs(g_normal, d_normal, gan_normal, scaled_data, e_norm, n_batch)
	# process each level of growth
	for i in range(1, len(g_models)):
		# retrieve models for this level of growth
		[g_normal, g_fadein] = g_models[i]
		[d_normal, d_fadein] = d_models[i]
		[gan_normal, gan_fadein] = gan_models[i]
		# scale dataset to appropriate size
		gen_shape = g_normal.output_shape
		scaled_data = scale_dataset(dataset, gen_shape[1:])
		print('Scaled Data', scaled_data.shape)
		# train fade-in models for next level of growth
		train_epochs(g_fadein, d_fadein, gan_fadein, scaled_data, e_fadein, n_batch, True)
		# train normal or straight-through models
		train_epochs(g_normal, d_normal, gan_normal, scaled_data, e_norm, n_batch)
		summarize_performance(i, g_normal, d_normal, dataset, latent_dim)

# %% [markdown]
# ## Training the Model
#
# No we start training the model, taking a snapshopt for each completed block (e.g. 4x4, 8x8,...).

# %%
# define models
d_models = define_discriminator(n_blocks)
# define models
g_models = define_generator(latent_dim, n_blocks)
# define composite models
gan_models = define_composite(d_models, g_models)
# load image data
dataset = load_real_samples()
# train model
train(g_models, d_models, gan_models, dataset, latent_dim, 200, 200, 8)
# Out:
# Scaled Data (17398, 4, 4, 3)
# d:\github\vaporwave-gan\vaporprogan\venv\lib\site-packages\keras\engine\training.py:493: UserWarning: Discrepancy between trainable weights and collected trainable weights, did you set `model.trainable` without calling `model.compile` after ?
#   'Discrepancy between trainable weights and collected trainable'
# d:\github\vaporwave-gan\vaporprogan\venv\lib\site-packages\keras\engine\training.py:493: UserWarning: Discrepancy between trainable weights and collected trainable weights, did you set `model.trainable` without calling `model.compile` after ?
#   'Discrepancy between trainable weights and collected trainable'
# d:\github\vaporwave-gan\vaporprogan\venv\lib\site-packages\keras\engine\training.py:493: UserWarning: Discrepancy between trainable weights and collected trainable weights, did you set `model.trainable` without calling `model.compile` after ?
#   'Discrepancy between trainable weights and collected trainable'
# Scaled Data (17398, 8, 8, 3)
# d:\github\vaporwave-gan\vaporprogan\venv\lib\site-packages\keras\engine\training.py:493: UserWarning: Discrepancy between trainable weights and collected trainable weights, did you set `model.trainable` without calling `model.compile` after ?
#   'Discrepancy between trainable weights and collected trainable'
# d:\github\vaporwave-gan\vaporprogan\venv\lib\site-packages\keras\engine\training.py:493: UserWarning: Discrepancy between trainable weights and collected trainable weights, did you set `model.trainable` without calling `model.compile` after ?
#   'Discrepancy between trainable weights and collected trainable'
# d:\github\vaporwave-gan\vaporprogan\venv\lib\site-packages\keras\engine\training.py:493: UserWarning: Discrepancy between trainable weights and collected trainable weights, did you set `model.trainable` without calling `model.compile` after ?
#   'Discrepancy between trainable weights and collected trainable'
# d:\github\vaporwave-gan\vaporprogan\venv\lib\site-packages\keras\engine\training.py:493: UserWarning: Discrepancy between trainable weights and collected trainable weights, did you set `model.trainable` without calling `model.compile` after ?
#   'Discrepancy between trainable weights and collected trainable'
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Scaled Data (17398, 16, 16, 3)
# d:\github\vaporwave-gan\vaporprogan\venv\lib\site-packages\keras\engine\training.py:493: UserWarning: Discrepancy between trainable weights and collected trainable weights, did you set `model.trainable` without calling `model.compile` after ?
#   'Discrepancy between trainable weights and collected trainable'
# d:\github\vaporwave-gan\vaporprogan\venv\lib\site-packages\keras\engine\training.py:493: UserWarning: Discrepancy between trainable weights and collected trainable weights, did you set `model.trainable` without calling `model.compile` after ?
#   'Discrepancy between trainable weights and collected trainable'
# d:\github\vaporwave-gan\vaporprogan\venv\lib\site-packages\keras\engine\training.py:493: UserWarning: Discrepancy between trainable weights and collected trainable weights, did you set `model.trainable` without calling `model.compile` after ?
#   'Discrepancy between trainable weights and collected trainable'
# d:\github\vaporwave-gan\vaporprogan\venv\lib\site-packages\keras\engine\training.py:493: UserWarning: Discrepancy between trainable weights and collected trainable weights, did you set `model.trainable` without calling `model.compile` after ?
#   'Discrepancy between trainable weights and collected trainable'
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Scaled Data (17398, 32, 32, 3)
# d:\github\vaporwave-gan\vaporprogan\venv\lib\site-packages\keras\engine\training.py:493: UserWarning: Discrepancy between trainable weights and collected trainable weights, did you set `model.trainable` without calling `model.compile` after ?
#   'Discrepancy between trainable weights and collected trainable'
# d:\github\vaporwave-gan\vaporprogan\venv\lib\site-packages\keras\engine\training.py:493: UserWarning: Discrepancy between trainable weights and collected trainable weights, did you set `model.trainable` without calling `model.compile` after ?
#   'Discrepancy between trainable weights and collected trainable'
# d:\github\vaporwave-gan\vaporprogan\venv\lib\site-packages\keras\engine\training.py:493: UserWarning: Discrepancy between trainable weights and collected trainable weights, did you set `model.trainable` without calling `model.compile` after ?
#   'Discrepancy between trainable weights and collected trainable'
# d:\github\vaporwave-gan\vaporprogan\venv\lib\site-packages\keras\engine\training.py:493: UserWarning: Discrepancy between trainable weights and collected trainable weights, did you set `model.trainable` without calling `model.compile` after ?
#   'Discrepancy between trainable weights and collected trainable'
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Scaled Data (17398, 64, 64, 3)
# d:\github\vaporwave-gan\vaporprogan\venv\lib\site-packages\keras\engine\training.py:493: UserWarning: Discrepancy between trainable weights and collected trainable weights, did you set `model.trainable` without calling `model.compile` after ?
#   'Discrepancy between trainable weights and collected trainable'
# d:\github\vaporwave-gan\vaporprogan\venv\lib\site-packages\keras\engine\training.py:493: UserWarning: Discrepancy between trainable weights and collected trainable weights, did you set `model.trainable` without calling `model.compile` after ?
#   'Discrepancy between trainable weights and collected trainable'
# d:\github\vaporwave-gan\vaporprogan\venv\lib\site-packages\keras\engine\training.py:493: UserWarning: Discrepancy between trainable weights and collected trainable weights, did you set `model.trainable` without calling `model.compile` after ?
#   'Discrepancy between trainable weights and collected trainable'
# d:\github\vaporwave-gan\vaporprogan\venv\lib\site-packages\keras\engine\training.py:493: UserWarning: Discrepancy between trainable weights and collected trainable weights, did you set `model.trainable` without calling `model.compile` after ?
#   'Discrepancy between trainable weights and collected trainable'
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Scaled Data (17398, 128, 128, 3)
# d:\github\vaporwave-gan\vaporprogan\venv\lib\site-packages\keras\engine\training.py:493: UserWarning: Discrepancy between trainable weights and collected trainable weights, did you set `model.trainable` without calling `model.compile` after ?
#   'Discrepancy between trainable weights and collected trainable'
# d:\github\vaporwave-gan\vaporprogan\venv\lib\site-packages\keras\engine\training.py:493: UserWarning: Discrepancy between trainable weights and collected trainable weights, did you set `model.trainable` without calling `model.compile` after ?
#   'Discrepancy between trainable weights and collected trainable'
# d:\github\vaporwave-gan\vaporprogan\venv\lib\site-packages\keras\engine\training.py:493: UserWarning: Discrepancy between trainable weights and collected trainable weights, did you set `model.trainable` without calling `model.compile` after ?
#   'Discrepancy between trainable weights and collected trainable'
# d:\github\vaporwave-gan\vaporprogan\venv\lib\site-packages\keras\engine\training.py:493: UserWarning: Discrepancy between trainable weights and collected trainable weights, did you set `model.trainable` without calling `model.compile` after ?
#   'Discrepancy between trainable weights and collected trainable'
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Scaled Data (17398, 256, 256, 3)
# d:\github\vaporwave-gan\vaporprogan\venv\lib\site-packages\keras\engine\training.py:493: UserWarning: Discrepancy between trainable weights and collected trainable weights, did you set `model.trainable` without calling `model.compile` after ?
#   'Discrepancy between trainable weights and collected trainable'
# ---------------------------------------------------------------------------
# ResourceExhaustedError                    Traceback (most recent call last)
# <ipython-input-52-0e071404e57b> in <module>
#      11 dataset = load_real_samples()
#      12 # train model
# ---> 13 train(g_models, d_models, gan_models, dataset, latent_dim, 200, 200, 8)
#
# <ipython-input-46-9c8a06954a73> in train(g_models, d_models, gan_models, dataset, latent_dim, e_norm, e_fadein, n_batch)
#      64                 print('Scaled Data', scaled_data.shape)
#      65                 # train fade-in models for next level of growth
# ---> 66                 train_epochs(g_fadein, d_fadein, gan_fadein, scaled_data, e_fadein, n_batch, True)
#      67                 # train normal or straight-through models
#      68                 train_epochs(g_normal, d_normal, gan_normal, scaled_data, e_norm, n_batch)
#
# <ipython-input-46-9c8a06954a73> in train_epochs(g_model, d_model, gan_model, dataset, n_epochs, n_batch, fadein)
#      31                 z_input = generate_latent_points(latent_dim, n_batch)
#      32                 y_real2 = ones((n_batch, 1))
# ---> 33                 g_loss = gan_model.train_on_batch(z_input, y_real2)
#      34
#      35 # scale images to preferred size
#
# d:\github\vaporwave-gan\vaporprogan\venv\lib\site-packages\keras\engine\training.py in train_on_batch(self, x, y, sample_weight, class_weight)
#    1447             ins = x + y + sample_weights
#    1448         self._make_train_function()
# -> 1449         outputs = self.train_function(ins)
#    1450         return unpack_singleton(outputs)
#    1451
#
# d:\github\vaporwave-gan\vaporprogan\venv\lib\site-packages\keras\backend\tensorflow_backend.py in __call__(self, inputs)
#    2977                     return self._legacy_call(inputs)
#    2978
# -> 2979             return self._call(inputs)
#    2980         else:
#    2981             if py_any(is_tensor(x) for x in inputs):
#
# d:\github\vaporwave-gan\vaporprogan\venv\lib\site-packages\keras\backend\tensorflow_backend.py in _call(self, inputs)
#    2935             fetched = self._callable_fn(*array_vals, run_metadata=self.run_metadata)
#    2936         else:
# -> 2937             fetched = self._callable_fn(*array_vals)
#    2938         return fetched[:len(self.outputs)]
#    2939
#
# d:\github\vaporwave-gan\vaporprogan\venv\lib\site-packages\tensorflow\python\client\session.py in __call__(self, *args, **kwargs)
#    1456         ret = tf_session.TF_SessionRunCallable(self._session._session,
#    1457                                                self._handle, args,
# -> 1458                                                run_metadata_ptr)
#    1459         if run_metadata:
#    1460           proto_data = tf_session.TF_GetBuffer(run_metadata_ptr)
#
# ResourceExhaustedError: OOM when allocating tensor with shape[8,128,256,256] and type float on /job:localhost/replica:0/task:0/device:GPU:0 by allocator GPU_0_bfc
# 	 [[{{node training_23/Adam/gradients/model_76/average_pooling2d_45/AvgPool_grad/AvgPoolGrad}}]]
# Hint: If you want to see a list of allocated tensors when OOM happens, add report_tensor_allocations_upon_oom to RunOptions for current allocation info.

# %% [markdown]
# # Calculating FID scores

# %%
g_model = load_model('generator_model_006.h5')
# Out:
# d:\github\vaporwave-gan\vaporprogan\venv\lib\site-packages\keras\engine\saving.py:310: UserWarning: No training configuration found in save file: the model was *not* compiled. Compile it manually.
#   warnings.warn('No training configuration found in save file: '

# %%
x_fake, y_fake = generate_fake_samples(g_model, latent_dim, n_samples=1000)

# %%
import os
os.mkdir('generated')

# %%
from PIL import Image
for i, x in enumerate(x_fake):
    im = Image.fromarray((x * 255).astype(np.uint8)).convert('RGB')
    im.save(f'./generated/{i}.png')

# %% [markdown]
# # Versioning Comments
#
# V1-V9:
#
# I mainly tried out the model and upped the epoch and block size to their target values of 6 blocks (128x128 images) and 100 epochs. The outcome is very interesting but mode collapse remains a problem. So after these version I used different learning rates for the discriminator and generator.
#
# V10-12:
#
# I also added label smoothing and corrected an issue in the production of the sample images.
#
# V15:
# Introducing sigmoid function
